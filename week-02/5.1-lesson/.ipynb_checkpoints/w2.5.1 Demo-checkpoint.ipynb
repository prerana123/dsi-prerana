# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib notebook

df = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.164809 -0.736930  1.247363  0.322660
# 1 -0.948561  0.902884  1.343980  1.582547
# 2  0.122729 -0.465304  0.753653  0.954479
# 3 -1.666318 -0.256056 -0.410311  1.459355
# 4 -0.518197 -0.844793  1.095115 -0.172090
# 5  1.939200 -0.642956  1.086041 -0.534816
# 6 -1.508490 -1.249505 -0.002193 -0.549733
# 7  0.108534  1.742134 -0.612855  0.065070
# 8  0.334593  0.255624 -0.278394 -0.143558
# 9  1.729389 -1.940608 -2.148221 -0.065552

# %%
df.plot.bar(stacked=True)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.barh()
#plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.scatter(x='a',y='b', c='r', s=134, label='test', title='Check it out\n')
# Out:
# <img src="data:image/png;base64,...">

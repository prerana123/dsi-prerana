# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("rock.csv")
df
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
df.dtypes
# Out:
# Song Clean      object
# ARTIST CLEAN    object
# Release Year    object
# COMBINED        object
# First?           int64
# Year?            int64
# PlayCount        int64
# F*G              int64
# dtype: object

# %%
print(df["First?"].mean(),df["PlayCount"].mean(),df["F*G"].mean())# mean by df fun.
#np.mean(df["First
# Out:
# (1.0, 16.872645739910315, 15.048430493273543)

# %%
df.shape #row and column(row,clm)
# Out:
# (2230, 8)

# %%
df.columns# name of clm
# Out:
# Index([u'Song Clean', u'ARTIST CLEAN', u'Release Year', u'COMBINED', u'First?',
#        u'Year?', u'PlayCount', u'F*G'],
#       dtype='object')

# %%
df1 = df
df1.sort_values("F*G")
df1.loc[1:10]
# Out:
#                 Song Clean   ARTIST CLEAN Release Year  \
# 1             Fantasy Girl    .38 Special          NaN
# 2          Hold On Loosely    .38 Special         1981
# 3   Rockin' Into the Night    .38 Special         1980
# 4        Art For Arts Sake           10cc         1975
# 5               Kryptonite   3 Doors Down         2000
# 6                    Loser   3 Doors Down         2000
# 7            When I'm Gone   3 Doors Down         2002
# 8               What's Up?  4 Non Blondes         1992
# 9               Take On Me           a-ha         1985
# 10   Baby, Please Don't Go          AC/DC          NaN
#
#                                  COMBINED  First?  Year?  PlayCount  F*G
# 1             Fantasy Girl by .38 Special       1      0          3    0
# 2          Hold On Loosely by .38 Special       1      1         85   85
# 3   Rockin' Into the Night by .38 Special       1      1         18   18
# ...

# %%
print(df["First?"].var(),df["PlayCount"].var(),df["F*G"].var())#varience
# Out:
# (0.0, 640.2403909332215, 639.5014668042713)

# %%
print(df["PlayCount"].std(),df["F*G"].std())
# Out:
# (25.30297197827207, 25.288366234382785)

# %%
#df2 = pd.read_csv("./assets/datasets/billboard.csv")

# %%
#df["PlayCount"].Range()

# %%
print(np.ptp(df["PlayCount"]))
# Out:
# 142

# %%
print(np.ptp(df["F*G"]))
# Out:
# 142

# %%
pd.pivot_table(df,index=["Song Clean"])
# Out:
#                                                       F*G  First?  PlayCount  \
# Song Clean
# #9 Dream                                              2.0     1.0        2.0
# (Don't Fear) The Reaper                              99.0     1.0       99.0
# (I Can't Get No) Satisfaction                        60.0     1.0       60.0
# (I Just) Died in Your Arms                            3.0     1.0        3.0
# (Oh) Pretty Woman                                    34.0     1.0       34.0
# (Sittin' On) The Dock of the Bay                      5.0     1.0        5.0
# (You Can Still) Rock in America                       3.0     1.0        3.0
# (You Gotta) Fight for Your Right (To Party)           4.0     1.0        4.0
# 18 And Life                                          17.0     1.0       17.0
# 1979                                                  3.0     1.0        3.0
# 1984/jump                                             3.0     1.0        3.0
# ...

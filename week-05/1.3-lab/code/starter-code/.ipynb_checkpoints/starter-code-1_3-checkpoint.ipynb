# %% [markdown]
# # Multi-table Datasets - ENRON Archive

# %% [markdown]
# ## 1. Data import
#
# Connect to the file 'assets/datasets/enron.db' using one of these methods:
#
# - sqlite3 python package
# - pandas.read_sql
# - SQLite Manager Firefox extension
#
# Take a look at the database and query the master table. How many Tables are there in the db?
#
# > Answer:
# There are 3 tables:
# - MessageBase
# - RecipientBase
# - EmployeeBase

# %%
import sqlite3
conn = sqlite3.connect('../../assets/datasets/enron.db')
c = conn.cursor()
conn.commit()
c.execute("SELECT name FROM sqlite_master WHERE type = 'table'").fetchall()
# Out:
# [(u'MessageBase',), (u'RecipientBase',), (u'EmployeeBase',)]

# %% [markdown]
# Query the `sqlite_master` table to retrieve the schema of the `EmployeeBase` table.
#
# 1. What fields are there?
# 1. What's the type of each of them?

# %%
# fetch = c.execute("SELECT * from sqlite_master;").fetchall()
# for row in fetch:
#     print row
#     print

# %%
fields = c.execute("SELECT sql from sqlite_master WHERE type ='table' and name='EmployeeBase';").fetchall()
print "".join(fields[0])

fields = c.execute("SELECT sql from sqlite_master WHERE type ='table' and name='MessageBase';").fetchall()
#print ''.join(fields[0])

fields = c.execute("SELECT sql from sqlite_master WHERE type ='table' and name='RecipientBase';").fetchall()
#print ''.join(fields[0])

#[12:02]
# Out:
# CREATE TABLE EmployeeBase (
#                   [eid] INTEGER,
#   [name] TEXT,
#   [department] TEXT,
#   [longdepartment] TEXT,
#   [title] TEXT,
#   [gender] TEXT,
#   [seniority] TEXT
#
#                   )

# %%
#import pandas as pd
import pandas as pd
from pandas.io import sql
sql.read_sql("SELECT * FROM EmployeeBase LIMIT 5",con =conn)
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
fields =c.execute("select sql from sqlite_master where type = 'table' and name = 'EmployeeBase';").fetchall()
print("".join(fields[0]))
#print ''.join(fields[0])
# Out:
# CREATE TABLE EmployeeBase (
#                   [eid] INTEGER,
#   [name] TEXT,
#   [department] TEXT,
#   [longdepartment] TEXT,
#   [title] TEXT,
#   [gender] TEXT,
#   [seniority] TEXT
#
#                   )

# %% [markdown]
# 1. Print the first 5 rows of EmployeeBase table
# 1. Print the first 5 rows of MessageBase table
# 1. Print the first 5 rows of RecipientBase table
#
# **Hint**  use `SELECT` and `LIMIT`.

# %%
res = c.execute("select * from EmployeeBase limit 5;").fetchall()
for row in res:
    print(row)
# Out:
# (1, u'John Arnold', u'Forestry', u'ENA Gas Financial', u'VP Trading', u'Male', u'Senior')
# (2, u'Harry Arora', u'Forestry', u'ENA East Power', u'VP Trading', u'Male', u'Senior')
# (3, u'Robert Badeer', u'Forestry', u'ENA West Power', u'Mgr Trading', u'Male', u'Junior')
# (4, u'Susan Bailey', u'Legal', u'ENA Legal', u'Specialist Legal', u'Female', u'Junior')
# (5, u'Eric Bass', u'Forestry', u'ENA Gas Texas', u'Trader', u'Male', u'Junior')

# %%
res1 = c.execute("select * from MessageBase limit 5;").fetchall()
for row in res1:
    print(row)
# Out:
# (1, u'taylor-m/sent/11', 910930020, u'Cd$ CME letter', 138)
# (2, u'taylor-m/sent/17', 911459940, u'Indemnification', 138)
# (3, u'taylor-m/sent/18', 911463840, u'Re: Indemnification', 138)
# (4, u'taylor-m/sent/23', 911874180, u'Re: Coral Energy, L.P.', 138)
# (5, u'taylor-m/sent/27', 912396120, u'Bankruptcy Code revisions', 138)

# %%
res2 = c.execute("select * from RecipientBase limit 5;").fetchall()
for row in res2:
    print(row)
# Out:
# (1, 1, 59)
# (2, 1, 15)
# (3, 1, 15)
# (4, 1, 109)
# (4, 2, 49)

# %%
sql.read_sql("select * from EmployeeBase limit 5",con = conn)
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
sql.read_sql("select * from MessageBase limit 5",con = conn)
# Out:
#    mid          filename  unix_time                    subject  from_eid
# 0    1  taylor-m/sent/11  910930020             Cd$ CME letter       138
# 1    2  taylor-m/sent/17  911459940            Indemnification       138
# 2    3  taylor-m/sent/18  911463840        Re: Indemnification       138
# 3    4  taylor-m/sent/23  911874180     Re: Coral Energy, L.P.       138
# 4    5  taylor-m/sent/27  912396120  Bankruptcy Code revisions       138

# %%
sql.read_sql("select * from RecipientBase limit 5",con = conn)
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49

# %% [markdown]
# Import each of the 3 tables to a Pandas Dataframes

# %%
employee = pd.read_sql('select * from EmployeeBase;',conn)
employee.head(5)
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
Recipients = pd.read_sql('select * from RecipientBase;',conn)
Recipients.head(5)
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49

# %%
Message = pd.read_sql('select * from MessageBase ;',conn)
Message.head(5)
# Out:
#    mid          filename  unix_time                    subject  from_eid
# 0    1  taylor-m/sent/11  910930020             Cd$ CME letter       138
# 1    2  taylor-m/sent/17  911459940            Indemnification       138
# 2    3  taylor-m/sent/18  911463840        Re: Indemnification       138
# 3    4  taylor-m/sent/23  911874180     Re: Coral Energy, L.P.       138
# 4    5  taylor-m/sent/27  912396120  Bankruptcy Code revisions       138

# %% [markdown]
# ## 3. Data Merging
#
# Use the pandas merge function to combine the information in the 3 dataframes to answer the following questions:
#
# 1. Are there more Men or Women employees?
# - How is gender distributed across departments?
# - Who is sending more emails? Men or Women?
# - What's the average number of emails sent by each gender?
# - Are there more Juniors or Seniors?
# - Who is sending more emails? Juniors or Seniors?
# - Which department is sending more emails? How does that relate with the number of employees in the department?
# - Who are the top 3 senders of emails? (people who sent out the most emails)

# %%
#8
sql.read_sql("select from_eid,count(mid) from MessageBase group by from_eid order by count(mid) desc",conn)
# Out:
#      from_eid  count(mid)
# 0          20        1597
# 1          59        1379
# 2         120        1142
# 3         131         859
# 4         138         658
# 5         130         654
# 6          39         443
# 7         145         409
# 8          91         403
# 9          95         395
# 10         34         366
# 11         65         361
# 12         61         354
# 13         67         354
# 14          1         341
# 15         48         322
# 16        117         322
# 17          5         318
# 18         46         318
# 19         43         316
# 20        151         302
# 21        122         295
# 22         24         290
# 23         92         273
# 24         74         260
# 25         69         249
# 26        137         244
# 27        144         237
# 28        149         227
# 29        118         224
# ..        ...         ...
# 122        55          12
# 123        14          10
# 124        22          10
# ...

# %%
a= sql.read_sql('''select e.gender, count(m.from_eid)  
from EmployeeBase as e 
join Message as m 
on e.eid == m.from_eid   
group by gender''', conn)
a# 3
# Out:
#   e.gender  count(m.from_eid)
# 0   Female               8794
# 1     Male              12841

# %%
#5
employee["seniority"].value_counts()
# Out:
# Junior    82
# Senior    74
# Name: seniority, dtype: int64

# %%
#6
sql.read_sql('''select e.seniority, count(m.from_eid)  
from EmployeeBase as e 
join Message as m 
on e.eid == m.from_eid   
group by seniority ''', conn)
# Out:
#   e.seniority  count(m.from_eid)
# 0      Junior               9196
# 1      Senior              12439

# %%
#7
sql.read_sql('''select e.department, count(e.eid)  
from EmployeeBase as e 
join Message as m 
on e.eid == m.from_eid   
group by  department''', conn)
# Out:
#   e.department  count(e.eid)
# 0     Forestry          4387
# 1        Legal         10396
# 2        Other          6852

# %%
#8
sql.read_sql('''select e.eid, count(m.mid)  
from EmployeeBase as e 
join Message as m 
on e.eid == m.from_eid group by m.from_eid  
order by count(m.mid)  desc''' , conn)
# Out:
#      e.eid  count(m.mid)
# 0       20          1597
# 1       59          1379
# 2      120          1142
# 3      131           859
# 4      138           658
# 5      130           654
# 6       39           443
# 7      145           409
# 8       91           403
# 9       95           395
# 10      34           366
# 11      65           361
# 12      61           354
# 13      67           354
# 14       1           341
# 15      48           322
# 16     117           322
# 17       5           318
# 18      46           318
# 19      43           316
# 20     151           302
# 21     122           295
# 22      24           290
# 23      92           273
# 24      74           260
# 25      69           249
# 26     137           244
# 27     144           237
# 28     149           227
# 29     118           224
# ..     ...           ...
# 122     55            12
# 123     14            10
# 124     22            10
# 125     35            10
# 126    124            10
# ...

# %%
a["e.gender"].value_counts()/employee["gender"].value_counts()
# Out:
# Male      0.008850
# Female    0.023256
# dtype: float64

# %%
employee["gender"].value_counts() # more men
# Out:
# Male      113
# Female     43
# Name: gender, dtype: int64

# %%
employee["gender"].count()
# Out:
# 156

# %%
employee["gender"].value_counts()/employee["gender"].count()
# Out:
# Male      0.724359
# Female    0.275641
# Name: gender, dtype: float64

# %%
employee.groupby("department")["gender"].value_counts()/employee.groupby("department")["gender"].count()
# Out:
# department  gender
# Forestry    Male      0.833333
#             Female    0.166667
# Legal       Female    0.520000
#             Male      0.480000
# Other       Male      0.718310
#             Female    0.281690
# Name: gender, dtype: float64

# %%
df = pd.merge(employee, Message, left_on='eid', right_on='from_eid')
df.gender.value_counts() / df.gender.count()
# Out:
# Male      0.593529
# Female    0.406471
# Name: gender, dtype: float64

# %%
df = pd.merge(employee, Message, left_on='eid', right_on='from_eid')
df.gender.value_counts()/df.gender.count()
# Out:
# Male      0.593529
# Female    0.406471
# Name: gender, dtype: float64

# %%
sql.read_sql("select e.gender, count(e.eid) 
             from EmployeeBase as e join Message as m on e.eid == m.from_eid  
             group by gender;", conn) # male
# Out:
#   File "<ipython-input-240-989e6e895fff>", line 1
#     sql.read_sql("select e.gender, count(e.eid)
#                                                ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## 2. Data Exploration
#
# Use the 3 dataframes to answer the following questions:
#
# 1. How many employees are there in the company?
# - How many messages are there in the database?
# - Convert the timestamp column in the messages. When was the oldest message sent? And the newest?
# - Some messages are sent to more than one recipient. Group the messages by message_id and count the number of recepients. Then look at the distribution of recepient numbers.
#     - How many messages have only one recepient?
#     - How many messages have >= 5 recepients?
#     - What's the highest number of recepients?
#     - Who sent the message with the highest number of recepients?
# - Plot the distribution of recepient numbers using Bokeh.

# %%
sql.read_sql("select count(eid) from employee", conn)
# Out:
#    count(eid)
# 0         156

# %%
sql.read_sql("select count(mid) from Message", conn)
# Out:
#    count(mid)
# 0       21635

# %%
sql.read_sql("select * from MessageBase where mid in(12116,12151)", conn)
# Out:
#      mid                      filename  unix_time subject  from_eid
# 0  12116  baughman-d/all_documents/398  990510780                67
# 1  12151       baughman-d/ect_admin/22  990546780                67

# %%
c = sql.read_sql(" select mid,count(to_eid) from RecipientBase group by mid order by 2 desc ",conn)
#c["count(to_eid)"].max()
c
# Out:
#          mid  count(to_eid)
# 0      12116             57
# 1      12151             57
# 2      12140             55
# 3      14404             52
# 4      16035             49
# 5      16431             24
# 6       8116             22
# 7      15148             21
# 8      15577             21
# 9      21103             20
# 10     21047             19
# 11     19671             18
# 12      6495             17
# 13     10087             17
# 14     11492             16
# 15     11516             16
# 16     12584             16
# 17     14194             16
# 18     14457             16
# 19     14547             16
# 20     18305             16
# 21     19028             16
# 22     21628             16
# 23      1355             15
# 24      5664             15
# 25      8945             15
# 26      8970             15
# 27      9154             15
# 28      9341             15
# 29     10624             15
# ...      ...            ...
# 21605  21599              1
# ...

# %%
#c = sql.read_sql(" select mid,count(to_eid) from RecipientBase group by mid order by 2 desc ",conn)

# %%
#sql.read_sql(" select mid,count(to_eid) from RecipientBase group by mid order by 2 desc ",conn)
# Out:
#          mid  count(to_eid)
# 0      12116             57
# 1      12151             57
# 2      12140             55
# 3      14404             52
# 4      16035             49
# 5      16431             24
# 6       8116             22
# 7      15148             21
# 8      15577             21
# 9      21103             20
# 10     21047             19
# 11     19671             18
# 12      6495             17
# 13     10087             17
# 14     11492             16
# 15     11516             16
# 16     12584             16
# 17     14194             16
# 18     14457             16
# 19     14547             16
# 20     18305             16
# 21     19028             16
# 22     21628             16
# 23      1355             15
# 24      5664             15
# 25      8945             15
# 26      8970             15
# 27      9154             15
# 28      9341             15
# 29     10624             15
# ...      ...            ...
# 21605  21599              1
# ...

# %%
#sql.read_sql(" select mid,count(to_eid) from RecipientBase group by mid having count(to_eid) >5 ",conn)

# %%
c["count(to_eid)"].value_counts()
# Out:
# 1     14985
# 2      2962
# 3      1435
# 4       873
# 5       711
# 6       180
# 7       176
# 8        61
# 13       57
# 11       47
# 12       33
# 10       29
# 15       28
# 9        24
# 14       11
# 16        9
# 21        2
# 17        2
# 57        2
# 22        1
# 52        1
# 20        1
# 55        1
# 19        1
# 24        1
# 18        1
# 49        1
# Name: count(to_eid), dtype: int64

# %%
sql.read_sql("select mid,max(to_eid) from RecipientBase",conn)
# Out:
#    mid  max(to_eid)
# 0  900          156

# %%
sql.read_sql("select mid, max(from_eid) from MessageBase",conn)
# Out:
#    mid  max(from_eid)
# 0  928            156

# %% [markdown]
# Rescale to investigate the tail of the curve

# %%
employe

# %% [markdown]
# Answer the following questions regarding received messages:
#
# - Who is receiving more emails? Men or Women?
# - Who is receiving more emails? Juniors or Seniors?
# - Which department is receiving more emails? How does that relate with the number of employees in the department?
# - Who are the top 5 receivers of emails? (people who received the most emails)

# %% [markdown]
# Which employees sent the most 'mass' emails?

# %% [markdown]
# Keep exploring the dataset, which other questions would you ask?
#
# Work in pairs. Give each other a challenge and try to solve it.

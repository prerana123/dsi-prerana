# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url=  "https://www.yelp.com/search?find_desc=Best+Restaurants&find_loc=Atlanta%2C+GA"
r =requests.get(url) 
r.content
# Out:
# '<!DOCTYPE HTML>\n\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js" lang="en"> <!--<![endif]-->\n    <head>\n\n\n    <script>            window.yPageStart = new Date().getTime();\n</script>\n\n    <script>            var initialVisibilityState = document.webkitVisibilityState;\n\n                yPerfTimings = [];\n\n                ySitRepParams = {"site": "main", "uniqueRequestID": "9b35c128aa8af4ea", "isLoggedIn": false, "clientIP": "96.89.86.225", 
# ...

# %%
#soup = BeautifulSoup(r.content)

# %%
 print soup.prettify()
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <!--<![endif]-->
#  <head>
#   <script>
#    window.yPageStart = new Date().getTime();
#   </script>
#   <script>
#    var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
# ...

# %%
for element in soup.find_all("a"): #link
    print element.get("href")
# Out:
# #header_find_form
# udwvwqdsuecacaavtbbb.html
# #header-nav
# #page-content
# /
# None
# /
# /user_details
# /writeareview
# /find_friends
# /mail
# /talk
# /events
# /signup
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3DBest%2BRestaurants%26find_loc%3DAtlanta%252C%2BGA
# javascript:;
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3DBest%2BRestaurants%26find_loc%3DAtlanta%252C%2BGA
# /signup
# /user_details
# /talk
# javascript:;
# javascript:;
# javascript:;
# /adredir?ad_business_id=16o53OC-1q875hpH8wdU8w&campaign_id=MBNYdwbPBfgGeMTeo5YSsA&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fjr-crickets-halftime-atlanta&request_id=afaa42a2fefbd5d6&signature=c397f202aacf2206a4192118833216ae4768ec1fa62d1592b17498d0a2555789&slot=0
# ...

# %%
d1 = soup.find_All("div",{"class": "biz-listing-large"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-7af4c5fcdf7f> in <module>()
# ----> 1 d1 = soup.find_All("div",{"class": "biz-listing-large"})
#
# TypeError: 'NoneType' object is not callable

# %%
url= "https://www.yelp.com/search?find_desc=Best+Restaurants&find_loc=Atlanta,+GA&start={}"
cities = ["nj","ny","atl"]
df = pd.DataFrame()
for city in cities:
    for i in range(0,20,10):
      LINK = url.format(i)
       r = requests.get(LINK)
        soup = BeautifulSoup(r.content)
         data = soup.find_all("div":"biz-listing-large"})

for element in  range(len(d1)):
    Name = d1[element].find("a",{"class":"name js-analytics-click"}).get_text().strip()
     Phone = d1[element].find("span", {"class": "biz-phone"}).get_text().strip()
    df = df.append({"name":Name,"Phone": Phone},ignore_index = True)
# Out:
#   File "<ipython-input-31-dea76e679365>", line 8
#     data = soup.find_all("div":"biz-listing-large"})
#                               ^
# SyntaxError: invalid syntax

# %%
df2 = df.append({"name":Name,"Phone": Phone},ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b170a2b0a2dd> in <module>()
# ----> 1 df2 = df.append({"name":Name,"Phone": Phone},ignore_index = True)
#
# NameError: name 'df' is not defined

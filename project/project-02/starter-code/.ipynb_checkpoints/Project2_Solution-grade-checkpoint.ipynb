# %% [markdown]
# # Project 2
# ## Step 1: Explore data
#
# ##### Load your data in using Pandas and start to explore. Save all of your early exploration code here and include in your final submission.

# %%
# Numeric and statistics packages:
import numpy as np
import scipy.stats as stats

# Pandas handles dataset loading and manipulation:
import pandas as pd

# import the plotting functions:
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# Initialize plotly notebook mode:
plotly.offline.init_notebook_mode()

# Setup matplotlib to display in notebook:
# %matplotlib inline
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.14.1
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
#Load Data File .
bd = pd.read_csv('../assets/billboard.csv')
bd.head(2)
# Out:
#    year  artist.inverted                     track  time genre date.entered  \
# 0  2000  Destiny's Child  Independent Women Part I  3:38  Rock   2000-09-23
# 1  2000          Santana              Maria, Maria  4:18  Rock   2000-02-12
#
#   date.peaked  x1st.week  x2nd.week  x3rd.week     ...      x67th.week  \
# 0  2000-11-18         78       63.0       49.0     ...             NaN
# 1  2000-04-08         15        8.0        6.0     ...             NaN
#
#    x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x74th.week  x75th.week  x76th.week
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
#
# [2 rows x 83 columns]

# %% [markdown]
# ##### Write a brief description of your data, data dictionary, and any interesting observations you've made thus far.

# %% [markdown]
# |Variable|Type|Description|
# |--|--|--|
# |Year|Integer|Year of Song|
# |artist inverted|String|Artist Name|
# |Track|String|Song Title|
# |Time|String|Song Time|
# |genre|String|Type of the Song|
# |date.entered|String|Date when song entered on billbord|
# |date.peaked|String|Date when song peaked|
# |week:1-76|Integer,Float|how long the song in billbord

# %% [markdown]
# our data file has top 100 charts of the year'00's, data is listed based on each artist, tracks and their weekly rating the current data is in a raw format and require some data massaging and slicing to perform better analytics and calculations.

# %% [markdown]
# ## Step 2: Clean data

# %% [markdown]
# ##### Do some rudimentary cleaning. Rename any columns that are poorly named, shorten any strings that are too long, and check for missing values (replace them and explain rationale if it makes sense).

# %%
#Drop column with all null value from Data Frames
bd1 = bd.dropna(axis=1,how = "all")

# %%
# to verify all null value column .
#bd.isnull()

# %%
#Columns "date.entered" and "date.peaked" are converted to datetime for ease of calculation
#and Time is converted to string

bd1.loc[:,"date.entered"] = pd.to_datetime(bd1.loc[:,"date.entered"])
bd1.loc[:,"date.peaked"] = pd.to_datetime(bd1.loc[:,"date.peaked"])
bd1.loc[:,"time"] = bd1.loc[:,"time"].astype(str)

#bd1.head(3)

# %%
#to check column with new data type.
bd1.dtypes
# Out:
# year                        int64
# artist.inverted            object
# track                      object
# time                       object
# genre                      object
# date.entered       datetime64[ns]
# date.peaked        datetime64[ns]
# x1st.week                   int64
# x2nd.week                 float64
# x3rd.week                 float64
# x4th.week                 float64
# x5th.week                 float64
# x6th.week                 float64
# x7th.week                 float64
# x8th.week                 float64
# x9th.week                 float64
# x10th.week                float64
# x11th.week                float64
# x12th.week                float64
# x13th.week                float64
# x14th.week                float64
# x15th.week                float64
# x16th.week                float64
# x17th.week                float64
# x18th.week                float64
# x19th.week                float64
# x20th.week                float64
# ...

# %%
# Code to convert time column to float for furthur calculations

list2 = []
list3 = []
for i in bd1["time"]:
    v1 = i
    v2 = v1.replace(":",".")
    list2.append(v2)

# %%
# Code to convert time column to float for furthur calculations 
list3 = list2 
list3 = map(float,list3)
bd1.loc[:,"time"] = list3

# %% [markdown]
# ##### Using Pandas' built in `melt` function, pivot the weekly Scoreing data to be long rather than wide. As a result, you will have removed the 72 'week' columns and replace it with two: Week and Scoreing. There will now be multiple entries for each song, one for each week on the Billboard Scoreings.

# %%
# Week columns were converted to rows and was assigned a Variable value using melt function
# this will make data more readable and ready for furthur processing
bd2 =pd.melt(bd1,id_vars = ['artist.inverted','track','genre','time', 'date.entered', 'date.peaked'],value_vars = list(bd1.iloc[:,7:]))

bd2.head(4)
# Out:
#    artist.inverted                     track genre  time date.entered  \
# 0  Destiny's Child  Independent Women Part I  Rock  3.38   2000-09-23
# 1          Santana              Maria, Maria  Rock  4.18   2000-02-12
# 2    Savage Garden        I Knew I Loved You  Rock  4.07   1999-10-23
# 3          Madonna                     Music  Rock  3.45   2000-08-12
#
#   date.peaked   variable  value
# 0  2000-11-18  x1st.week   78.0
# 1  2000-04-08  x1st.week   15.0
# 2  2000-01-29  x1st.week   71.0
# 3  2000-09-16  x1st.week   41.0

# %%
#Added Days to Peak Column by substracting Date Peaked from Date Entered
bd2.loc[:,"days_to_peak"] = bd2.loc[:,"date.peaked"]-bd2.loc[:,"date.entered"]
bd2.head(4)
# Out:
#    artist.inverted                     track genre  time date.entered  \
# 0  Destiny's Child  Independent Women Part I  Rock  3.38   2000-09-23
# 1          Santana              Maria, Maria  Rock  4.18   2000-02-12
# 2    Savage Garden        I Knew I Loved You  Rock  4.07   1999-10-23
# 3          Madonna                     Music  Rock  3.45   2000-08-12
#
#   date.peaked   variable  value  days_to_peak
# 0  2000-11-18  x1st.week   78.0       56 days
# 1  2000-04-08  x1st.week   15.0       56 days
# 2  2000-01-29  x1st.week   71.0       98 days
# 3  2000-09-16  x1st.week   41.0       35 days

# %%
#Value Variable="x1st.week...etc" is good to read but is not good to perform any calculations
#on varibale column converting this to No of Weeks which will be useful later on for 
#plotting weekly graphs
list1= []
for i in bd2["variable"]:
    v1 = i
    v2 = v1.replace("x","").replace("th","").replace("st","").replace("rd","").replace("nd","").replace(".week","")         
    list1.append(v2)
list1 = map(int,list1)

# %%
bd2["variable"] = list1
bd2.head(2)
bd2.shape
# Out:
# (20605, 9)

# %% [markdown]
# As matter of policy, Billboard removes former hits from the Hot 100 once they drop below 50. Billboard’s reasoning is that it gives new songs and new artists a better chance at getting on the charts. That’s probably a good thing from a music industry reporting perspective, but it’s not good from our data science perspective.Perhaps the best approach is to simply only pay attention to Scoreings from 1- 50.

# %%
#JB great, do you have a link to a site or article on this?

# %%
#Messaged the Data to Include only top 50 ratings as that will make more sence due 
#to above mentioned Billboard policy
#Also Included a Score Column by a calculating 51 - Value(Rating) this no will be 
#later on Score will be summed up to calculate various results   
#Higer the Score more popular the track,artist or genre
bd3 = bd2[bd2["value"]<50]
bd3.loc[:,"value"] = bd3.loc[:,"value"].astype(int)
bd3.loc[:,"Score"] = 51-bd3.loc[:,"value"]
bd3.head(4)
# Out:
#                  artist.inverted         track genre  time date.entered  \
# 1                        Santana  Maria, Maria  Rock  4.18   2000-02-12
# 3                        Madonna         Music  Rock  3.45   2000-08-12
# 30                        N'Sync   Bye Bye Bye  Rock  3.15   2000-01-29
# 35  Elliott, Missy "Misdemeanor"      Hot Boyz   Rap  3.51   1999-11-27
#
#    date.peaked  variable  value  days_to_peak  Score
# 1   2000-04-08         1     15       56 days     36
# 3   2000-09-16         1     41       35 days     10
# 30  2000-04-15         1     42       77 days      9
# 35  2000-01-08         1     36       42 days     15

# %%
#Renamed Variable column to week ,value to rating etc...
bd4 = bd3.rename(columns = {"variable":"week","value": "rating","genre":"genre","artist.inverted":"artist"})
bd4.head(10)
# Out:
#                           artist              track    genre  time  \
# 1                        Santana       Maria, Maria     Rock  4.18
# 3                        Madonna              Music     Rock  3.45
# 30                        N'Sync        Bye Bye Bye     Rock  3.15
# 35  Elliott, Missy "Misdemeanor"           Hot Boyz      Rap  3.51
# 45                          Pink         There U Go     Rock  3.23
# 52          Backstreet Boys, The  Shape Of My Heart     Rock  3.49
# 60                 Martin, Ricky          She Bangs    Latin  4.02
# 74             Dixie Chicks, The       Goodbye Earl  Country  4.19
# 75                           Guy            Dancin'      R&B  4.08
# 76                   Lil Bow Wow     Bounce With Me      Rap  3.22
#
#    date.entered date.peaked  week  rating  days_to_peak  Score
# 1    2000-02-12  2000-04-08     1      15       56 days     36
# 3    2000-08-12  2000-09-16     1      41       35 days     10
# ...

# %% [markdown]
# ## Step 3: Visualize your data.

# %% [markdown]
# ##### Using BOTH a Tableau Dashboard and python, create visualizations that will provide context to your data. There is no minimum or maximum number of graphs you should generate, but there should be a clear and consistent story being told. Give insights to the distribution, statistics, and relationships of the data.

# %% [markdown]
# We will make pivots tables on Track,Artist and Genre. we will fond out best performing songs , artists by calculating sum of score on each pivot.
# We will also draw a scatter plot on top Artist,Track and Genre
# We will also use tablue to plot best performing artist and their tracks in order of performance score.
# We will try to find out correlating between time of a song and over all popularity using tablue.

# %%
# pivot table for each track with score
time_table = pd.DataFrame(pd.pivot_table(bd4,index =['track','time'],values = ['Score'],aggfunc='sum'))
time_table
t1=time_table.sort_values(by ="Score",ascending=False )
Top_20_Track = t1.head(20)
Top_20_Track

#Top_20_Track.to_csv('Top_20_Track.csv', sep='\t')

#week_tble.to_csv('Week_table.csv', sep='\t')
# Out:
#                                         Score
# track                             time
# Breathe                           4.04   1541
# Kryptonite                        3.53   1408
# I Wanna Know                      4.57   1406
# Amazed                            4.25   1366
# Bent                              4.12   1271
# Everything You Want               4.01   1241
# With Arms Wide Open               3.52   1190
# I Knew I Loved You                4.07   1130
# He Wasn't Man Enough              4.21   1126
# Try Again                         4.03   1109
# Maria, Maria                      4.18   1053
# Independent Women Part I          3.38   1052
# There U Go                        3.23   1036
# Say My Name                       4.31   1028
# Higher                            5.16   1006
# My Love Is Your Love              4.16    975
# Jumpin' Jumpin'                   3.48    971
# Case Of The Ex (Whatcha Gonna Do) 3.50    969
# ...

# %%
#pivot table for artist with score
Artist_Rating =pd.DataFrame(pd.pivot_table(bd4,index =['artist'],values = 'Score',aggfunc= "sum"))
Artist_Score = Artist_Rating.sort_values(by ="Score",ascending=False, )
Top_20= Artist_Score.head(20)
Top_20
# Out:
#                       Score
# artist
# Destiny's Child        3051
# N'Sync                 2461
# Creed                  2196
# Aguilera, Christina    2028
# Pink                   1879
# Sisqo                  1728
# Lonestar               1584
# Vertical Horizon       1552
# Hill, Faith            1541
# 3 Doors Down           1408
# Joe                    1406
# Savage Garden          1327
# Backstreet Boys, The   1273
# matchbox twenty        1271
# Aaliyah                1248
# Braxton, Toni          1234
# Houston, Whitney       1071
# Santana                1053
# Madonna                1017
# Jay-Z                   996

# %%
Top_20.plot(kind='bar')
plt.show()

# %%
# scatter plot for artist with highest rating.
dfScatter = bd4[bd4["artist"] == ("Destiny's Child")]
dfScatter.plot(kind='scatter', x="week", y="rating");
plt.gca().invert_yaxis()

# %%
# pivot table for track with score
Track_Rating =pd.DataFrame(pd.pivot_table(bd4,index =['track'],values = 'Score',aggfunc= "sum"))
Track_Score = Track_Rating.sort_values(by ="Score",ascending=False, )
Top_20_Track = Track_Score.head(20)

Top_20_Track
# Out:
#                                    Score
# track
# Breathe                             1541
# Kryptonite                          1408
# I Wanna Know                        1406
# Amazed                              1366
# Bent                                1271
# Everything You Want                 1241
# With Arms Wide Open                 1190
# I Knew I Loved You                  1130
# He Wasn't Man Enough                1126
# Try Again                           1109
# Maria, Maria                        1053
# Independent Women Part I            1052
# There U Go                          1036
# Say My Name                         1028
# Higher                              1006
# My Love Is Your Love                 975
# Jumpin' Jumpin'                      971
# Case Of The Ex (Whatcha Gonna Do)    969
# Thong Song                           926
# You Sang To Me                       909

# %%
Top_20_Track.plot(kind='bar')
plt.show()

# %%
dfScatter = bd4[bd4["track"] == ("Breathe")]
#dfScatter = bd4[bd4["track"] == (Top_Track)]
dfScatter.plot(kind='scatter', x="week", y="rating");
plt.gca().invert_yaxis()

# %%
#pivot table for genre 
Genre_Rating =pd.DataFrame(pd.pivot_table(bd4,index =['genre'],values = 'Score',aggfunc="sum"))
Genre_Score = Genre_Rating.sort_values(by ="Score",ascending=False, )
Top_5_Genre = Genre_Score.head(5)
Top_5_Genre
# Out:
#          Score
# genre
# Rock     46591
# Rap       8788
# Country   5548
# Latin     2444
# Pop       1465

# %%
Top_5_Genre.plot(kind='bar')
plt.show()

# %% [markdown]
# By Looking at the Genre Score graph we can determine that rock music was one of the most popular genre during 2000's all songs. There is a huge difference between popularity of Rock music compared to other Genre.

# %%
# By looking at Scatter plot of rock music, we see that it has achived top rating's for good part of the year.
dfScatter = bd4[bd4["genre"] == ("Rock")]
dfScatter.plot(kind='scatter', x="week", y="rating");
plt.gca().invert_yaxis()

# %%
# from IPython.display import Image
# Image('assets/Top5ArtistTrack.png')
from IPython.display import Image
Image('../assets//Top5ArtistTrack.png')

# %%
time_table = pd.DataFrame(pd.pivot_table(bd4,index =['track','time'],values = ['Score'],aggfunc='sum'))
time_table
Time_score_Graph=time_table.sort_values(by ="Score",ascending=False )
Top_20_Track = Time_score_Graph.head(20)
Top_20_Track
# Out:
#                                         Score
# track                             time
# Breathe                           4.04   1541
# Kryptonite                        3.53   1408
# I Wanna Know                      4.57   1406
# Amazed                            4.25   1366
# Bent                              4.12   1271
# Everything You Want               4.01   1241
# With Arms Wide Open               3.52   1190
# I Knew I Loved You                4.07   1130
# He Wasn't Man Enough              4.21   1126
# Try Again                         4.03   1109
# Maria, Maria                      4.18   1053
# Independent Women Part I          3.38   1052
# There U Go                        3.23   1036
# Say My Name                       4.31   1028
# Higher                            5.16   1006
# My Love Is Your Love              4.16    975
# Jumpin' Jumpin'                   3.48    971
# Case Of The Ex (Whatcha Gonna Do) 3.50    969
# ...

# %% [markdown]
# Null Hypothesis:- My null hypothesis is there is no relation between time duration of song and over all rating of song.
# Alternative Hypothesis :- There is a inverse relation between time duration of song and rating of song. By that we mean lenghty songs are generally less popular, One of the reason could be that they will get less air time on radio. and people will not be very intrested in listening long songs.
#
# To Test my hypothesis hypothesis i used the graph between score and time duration of track,

# %% [markdown]
# I Used Tablue to find relation between time and score for every song, and after this i got to know that my alternative hypothesis is true there is a relation between time and score. Audience dont like lenghty songs. and i got to know there is normal distribution btween time and score.

# %%
#Time_score_Graph.to_csv('Top_20_Track.csv', sep='\t')
from IPython.display import Image
Image('../assets/Time_Rank.png')

# %% [markdown]
# ## Step 4: Create a Problem Statement.
#
# ##### Having explored the data, come up with a problem statement that includes risks and assumptions for this data set. You can feel free to introduce data from any other source to support your problem statement, just be sure to provide a link to the origin of the data. Once again- be creative!
#
# - Guide: http://www.ceptara.com/blog/how-to-write-problem-statement
# - Kaggle example: https://www.kaggle.com/c/inria-bci-challenge
# - Kaggle example: https://www.kaggle.com/c/axa-driver-telematics-analysis

# %% [markdown]
# Problem Statement:- Songs are a part of life however it is always intresting to know which Songs,Artist  have performed best through out an year. Today by analysing tracks of '00's we will try to figure out best songs, artist's genre of the year, we will also perform some stastical analysis to figure out some intresting relationships.

# %%
#JB what's the problem? Per Step 3 comments, maybe you work for a record label that asks which attributes most strongly
# correlate to popularity?

# %% [markdown]
# ## Step 5: Brainstorm your Approach.
# ##### In bullet-list form, provide a proposed approach for evaluating your problem statement. This can be somewhat high-level, but start to think about ways you can massage the data for maximum efficacy.

# %% [markdown]
# To find out Best songs ,Artists  perform following operatios.
#  1 Perform Data cleaning and try to eleiminate any null values without loosing any important data
#  2 Change datatypes for calculation and rename column for better understanding of data.
#  3 To perform data calculations did some rudementry analysis and data massaging.
#  4 Polt different relation ship plots and graph's.
#  5 Introduce some new data columns for better stastical analysis.

# %%
#JB use markdown numbered list for this

# %% [markdown]
# ## Step 6: Create a blog post with your code snippets and visualizations.
# ##### Data Science is a growing field, and the Tech industry thrives off of collaboration and sharing of knowledge. Blogging is a powerful means for pushing the needle forward in our field. Using your blogging platform of choice, create a site and post your process and results. Rather than writing a procedural text, imagine you're describing the data, visualizations, and conclusions you've arrived at to your peers.

# %% [markdown]
# https://preranashrivastava.wordpress.com/2016/11/06/analyzing-billboard-chart-finding-top-songs-artists-of-year-2000/

# %%
#JB nice! Create an about page and link to LinkedIn!

# %% [markdown]
# ### BONUS: LinkedIn has recognized you as a DS thought leader and asked you to pen a white paper (~500 words) on 'Best Practices for Clean Data'. This will be an opinion piece read by a wide (including semi-technical) audience, so be sure to back up your statements with real world examples or scenarios.
#
# ##### Hint: Look for online resources (articles, blogs, papers, youtube, podcasts, reddit) that will help you understand the challenges and implications of dealing with big data and missing data. This should be a personal reflection on everything you've learned this week, and the learning goals that have been set out for you going forward.

# %% [markdown]
# https://preranashrivastava.wordpress.com/what-is-clean-data-a-white-paper

# %%
#JB very good! I want more technical code, like sharing some PYTHON that helps you clean up your data.

# %% [markdown]
# Score | 22/24
# ----- | ------
# Identify: Problem Statement / Hypothesis	| 2
# Identify: Risks & Assumptions				| 2
# Acquire: Import Data Using Pandas			| 3
# Parse: Perform EDA Using Pandas				| 3
# Viz: Tableau Dashboard and Plots			| 1
# Mine: Determine Correlations				| 2
# Refine: Evaluate Findings				    | 3
# Present: Describe Results in Blog Post		| 3
# Bonus! Present: Write a short White Paper	| 3/5

# %% [markdown]
# #JB I can't find your Tableau dashboard. For future assignments, please upload the graphs to Tableau Public and load them straight in your notebook. Ask Alex or other students for help if needed; many are using this approach. Very good overall!

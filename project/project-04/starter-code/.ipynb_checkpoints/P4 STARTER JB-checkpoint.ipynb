# %% [markdown]
# # Project 4: Web Scraping Indeed.com & Predicting Salaries

# %% [markdown]
# In Project 4, we practice two major skills: collecting data via  web scraping and building a binary predictor with Logistic Regression.
#
# We will collect salary information on data science jobs in a variety of markets. Using location, title, and job summary, we'll predict the salary of the job. For job posting sites, this is extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), extrapolating expected salary can help guide negotiations.
#
# Normally, we can use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Q: Why would we want this to be a classification problem?
# - A: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Section one focuses on scraping Indeed.com; then we use listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# Scrape job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries. First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)
#
# The URL here has many query parameters
#
# - `q` for the job search
# - This is followed by "+20,000" to return results with salaries (or expected salaries >$20,000)
# - `l` for a location
# - `start` for what result number to start on

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist&l=Atlanta%2C+GA"

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
# read site in soup
r = requests.get(URL)
soup = BeautifulSoup(r.content, "lxml")

# Append to the full set of results
results = soup.findAll('div', { "class" : "result" })
#results
#results[1]

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some of the more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available
# - Test the functions on the results above

# %%
# get text
def extract_text(el):
    if el:
        return el.text.strip()
    else:
        return ''
        
# company
def get_company_from_result(result):
    return extract_text(result.find('span', {'class' : 'company'}))

# location
def get_location_from_result(result):
    return extract_text(result.find('span', {'class' : 'location'}))



# summary
def get_summary_from_result(result):
    return extract_text(result.find('span', {'class' : 'summary'}))



# title
def get_title_from_result(result):
    return extract_text(result.find('a', {'data-tn-element' : 'jobTitle'}))



# get salary if exists
def get_salary_from_result(result):
    salary_table = result.find('td', {'class' : 'snip'})
    if salary_table:
        snip = salary_table.find('nobr')
        if snip:
            return snip.text.strip()   
    return None

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results: the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try different city). The second controls where in the results to start and gives 10 results (so we can keep incrementing this by 10 to move further within the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and start points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
# specify city
YOUR_CITY = ['Atlanta','Newark','Dallas','New+York','Houston', 'Boston','Connecticut',"San+Francisco",'Seattle','Cleveland','Tampa','Miami']
import pandas as pd

# %%
#create template URL and max number of results (pages) to pull
# url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
# df =pd.DataFrame()
# # for loop to pull data with bs4
# for city in YOUR_CITY :
#     for start in range(1,500,10):
#         r = requests.get(url_template.format(city,start))
#         # Grab the results from the request (as above)
#         soup = BeautifulSoup(r.content)
#         # Append to the full set of results
#         results += soup.findAll('div', { "class" : "result" })
# #a = get_location_from_result(results) 
# for element in  range(len(results)):
#     company = get_company_from_result(results[element])
#     location =get_location_from_result(results[element])
#     summary=get_summary_from_result(results[element])
#     title=get_title_from_result(results[element])
#     salary=get_salary_from_result(results[element])
# #     df = df.append({"Location":location,"Summary":summary,"Title":title,"Salary":salary},ignore_index = True)
#     df = df.append({"Company":company,"Location":location,"Title":title,"Salary":salary,"Summary":summary},ignore_index = True)
# df
# Out:
#                                          Company              Location  \
# 0                                       Cotiviti           Atlanta, GA
# 1                                 Cox Automotive           Atlanta, GA
# 2                                      Honeywell           Atlanta, GA
# 3                                     FraudScope           Atlanta, GA
# 4                         Vision3 Solutions, Inc           Atlanta, GA
# 5                         eTek IT Services, Inc.           Atlanta, GA
# 6                                          Infor           Atlanta, GA
# 7                                         Google           Atlanta, GA
# 8                                    IgnitionOne           Atlanta, GA
# 9                                         Macy's           Atlanta, GA
# 10                              Pivotal Software           Atlanta, GA
# 11                                          AT&T        Alpharetta, GA
# 12    Centers for Disease Control and Prevention           Atlanta, GA
# 13                               MobileDev Power     Atlanta, GA 30305
# 14                            Predictive Science         United States
# 15                               MobileDev Power     Atlanta, GA 30305
# 16                                Cox Automotive           Atlanta, GA
# 17                                    Home Depot     Atlanta, GA 30354
# 18                                           ICF           Atlanta, GA
# 19                                     Ashton212           Atlanta, GA
# 20                                     Honeywell           Atlanta, GA
# 21                                      GE Power           Atlanta, GA
# 22                              Northrop Grumman           Atlanta, GA
# 23                               Lockheed Martin    Marietta, GA 30063
# 24                   Eagle Medical Services, LLC           Atlanta, GA
# 25                        Cardlytics Corporation           Atlanta, GA
# 26                                        Turner     Atlanta, GA 30319
# 27                                     Honeywell           Atlanta, GA
# 28                                     Honeywell           Atlanta, GA
# 29                            Predictive Science         United States
# ...                                          ...                   ...
# 8866                        Amazon Corporate LLC         United States
# 8867                       Beckman Coulter, Inc.             Miami, FL
# 8868                        Amazon Corporate LLC         United States
# 8869                Altor BioScience Corporation           Miramar, FL
# 8870                          Predictive Science         United States
# 8871                                         HBI             Miami, FL
# 8872               Chicago Bridge & Iron Company       Miami Lakes, FL
# 8873                       Beckman Coulter, Inc.             Miami, FL
# 8874                               Wantman Group   Fort Lauderdale, FL
# 8875                                 Osthus Inc.  Plantation, FL 33324
# 8876                               Audible, Inc.         United States
# 8877                        Amazon Corporate LLC         United States
# 8878                        Amazon Corporate LLC         United States
# 8879                        Amazon Corporate LLC         United States
# 8880                   Amazon Web Services, Inc.         United States
# 8881                        Amazon Corporate LLC         United States
# 8882                       Beckman Coulter, Inc.             Miami, FL
# 8883                          Predictive Science         United States
# 8884                                         HBI             Miami, FL
# 8885               Chicago Bridge & Iron Company       Miami Lakes, FL
# 8886                       Beckman Coulter, Inc.             Miami, FL
# 8887                               Wantman Group   Fort Lauderdale, FL
# 8888                                 Osthus Inc.  Plantation, FL 33324
# 8889                               Audible, Inc.         United States
# 8890                        Amazon Corporate LLC         United States
# 8891                        Amazon Corporate LLC         United States
# 8892                        Amazon Corporate LLC         United States
# 8893                   Amazon Web Services, Inc.         United States
# 8894                        Amazon Corporate LLC         United States
# 8895                       Beckman Coulter, Inc.             Miami, FL
#
#                          Salary  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                   $90 an hour
# 5                   $67 an hour
# 6                          None
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12    $88,305 - $114,802 a year
# 13                         None
# 14                         None
# 15                         None
# 16                         None
# 17                         None
# 18                         None
# 19                         None
# 20                         None
# 21                         None
# 22                         None
# 23                         None
# 24                         None
# 25                         None
# 26                         None
# 27                         None
# 28                         None
# 29                         None
# ...                         ...
# 8866                       None
# 8867                       None
# 8868                       None
# 8869                       None
# 8870                       None
# 8871                       None
# 8872                       None
# 8873                       None
# 8874                       None
# 8875                       None
# 8876                       None
# 8877                       None
# 8878                       None
# 8879                       None
# 8880                       None
# 8881                       None
# 8882                       None
# 8883                       None
# 8884                       None
# 8885                       None
# 8886                       None
# 8887                       None
# 8888                       None
# 8889                       None
# 8890                       None
# 8891                       None
# 8892                       None
# 8893                       None
# 8894                       None
# 8895                       None
#
#                                                 Summary  \
# 0     This is a pioneering data scientist who will p...
# 1     Interprets problems and develops solutions to ...
# 2     Support and mentor data scientists. Minimum of...
# 3     Experience with healthcare-related data and fa...
# 4     Data Scientist- Big Data*. May write code to a...
# 5     Interacts with data scientists and industry ex...
# 6     Senior Data Scientist. Working closely with Pr...
# 7     The Google Cloud training team already develop...
# 8     Have experience with predictive modelling / da...
# 9     Uses analytical rigor and statistical methods,...
# 10    If you bring a deep focus and passion for a pa...
# 11    Perform data studies and data discovery around...
# 12    Whether we are protecting the American people ...
# 13    Authoritative quantitative analysis skills, pa...
# 14    This is a freelance data scientist position wh...
# 15    Build scalable predictive models based on data...
# 16    Description Cox Automotive is hiring a Data Sc...
# 17    Strong communication and data presentation ski...
# 18    Evaluate data errors and work to resolve data ...
# 19    The Important Stuff A leader in the payments i...
# 20    Advanced analytics/modelling projects, includi...
# 21    Ability to create and understand data models. ...
# 22    Perform data entry, cleaning, and analysis (bo...
# 23    Experience with full-scale pole model design, ...
# 24    Comfortable in collaborating with data scienti...
# 25    50 concurrent data scientists and analysts. Bu...
# 26    Has experience with SQL, R, SPSS, Tableau, Pow...
# 27    Work closely with data scientists and product ...
# 28    Support and mentor data scientists. Experience...
# 29    This is a freelance data scientist position wh...
# ...                                                 ...
# 8866  As a Principal, you will provide leadership to...
# 8867  Assist management in special assignments desig...
# 8868  Computer Science fundamentals in object-orient...
# 8869  Compile data to support/contribute to technica...
# 8870  This is a freelance data scientist position wh...
# 8871  Topic: Laboratory Testing Patterns/Profitabili...
# 8872  Collection and interpretation/evaluation of sc...
# 8873  Scientists use our life science research instr...
# 8874  Office work – including data management, prepa...
# 8875  To translate technical writing into commonly u...
# 8876  Do you enjoy working with Data Scientists to w...
# 8877  Experience with very large-scale data and the ...
# 8878  Are you interested in building data pipelines ...
# 8879  We specifically seek candidates who want to jo...
# 8880  Strong at applying data structures, algorithms...
# 8881  As a Principal, you will provide leadership to...
# 8882  Assist management in special assignments desig...
# 8883  This is a freelance data scientist position wh...
# 8884  Topic: Laboratory Testing Patterns/Profitabili...
# 8885  Collection and interpretation/evaluation of sc...
# 8886  Scientists use our life science research instr...
# 8887  Office work – including data management, prepa...
# 8888  To translate technical writing into commonly u...
# 8889  Do you enjoy working with Data Scientists to w...
# 8890  Experience with very large-scale data and the ...
# 8891  Are you interested in building data pipelines ...
# 8892  We specifically seek candidates who want to jo...
# 8893  Strong at applying data structures, algorithms...
# 8894  As a Principal, you will provide leadership to...
# 8895  Assist management in special assignments desig...
#
#                                                   Title
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                Principal Data Scientist - Atlanta, GA
# 3                                        Data Scientist
# 4                              Data Scientist- Big Data
# 5                                     Big Data Engineer
# 6                                    Sr. Data Scientist
# 7     Cloud Instructor (Big Data, Machine Learning),...
# 8                                        Data Scientist
# 9                                        Data Scientist
# 10                                   Sr. Data Scientist
# 11       AT&T Professional Data Scientist Alpharetta GA
# 12                                Statistician (Health)
# 13              Data Scientist With Predictive Modeling
# 14                                       Data Scientist
# 15              Data Scientist With Predictive Modeling
# 16                                       Data Scientist
# 17                                       DATA SCIENTIST
# 18                              Scientific Data Analyst
# 19                          Quantitative Analyst | #769
# 20                            Analytics DevOps Engineer
# 21                     IT Project Manager – Sourcing BI
# 22                          HAI Prevention Data Analyst
# 23                            Research Scientist Senior
# 24                                         Data Analyst
# 25                              Principal Data Engineer
# 26    Manager, Consumer Insights & Statistical Analysis
# 27                                   Big Data Architect
# 28               Principal Data Scientist - Atlanta, GA
# 29                                       Data Scientist
# ...                                                 ...
# 8866  Principal Data Scientist - Consumer Website- R...
# 8867                                      Accountant II
# 8868  Software Development Engineer – Emerging AWS M...
# 8869             Associate Scientist, Assay Development
# 8870                                     Data Scientist
# 8871  PhD Level Dissertation Researcher/Writer/Edito...
# 8872                            Environmental Scientist
# 8873                                    Manager Finance
# 8874           Environmental Scientist - Ft. Lauderdale
# 8875                    Scientific Domain Modeler (f/m)
# 8876  Software Development Engineer, Data Science- R...
# 8877  Principal Research Scientist- Relocation Oppor...
# 8878  Software Development Engineer, Big Data- Reloc...
# 8879  Software Development Engineer, Big Data Analyt...
# 8880  Software Development Engineer - AWS & Machine ...
# 8881  Principal Data Scientist - Consumer Website- R...
# 8882                                      Accountant II
# 8883                                     Data Scientist
# 8884  PhD Level Dissertation Researcher/Writer/Edito...
# 8885                            Environmental Scientist
# 8886                                    Manager Finance
# 8887           Environmental Scientist - Ft. Lauderdale
# 8888                    Scientific Domain Modeler (f/m)
# 8889  Software Development Engineer, Data Science- R...
# 8890  Principal Research Scientist- Relocation Oppor...
# 8891  Software Development Engineer, Big Data- Reloc...
# 8892  Software Development Engineer, Big Data Analyt...
# 8893  Software Development Engineer - AWS & Machine ...
# 8894  Principal Data Scientist - Consumer Website- R...
# 8895                                      Accountant II
#
# [8896 rows x 5 columns]

# %%
df
# Out:
#                                          Company              Location  \
# 0                                       Cotiviti           Atlanta, GA
# 1                                 Cox Automotive           Atlanta, GA
# 2                                      Honeywell           Atlanta, GA
# 3                                     FraudScope           Atlanta, GA
# 4                         Vision3 Solutions, Inc           Atlanta, GA
# 5                         eTek IT Services, Inc.           Atlanta, GA
# 6                                          Infor           Atlanta, GA
# 7                                         Google           Atlanta, GA
# 8                                    IgnitionOne           Atlanta, GA
# 9                                         Macy's           Atlanta, GA
# 10                              Pivotal Software           Atlanta, GA
# 11                                          AT&T        Alpharetta, GA
# 12    Centers for Disease Control and Prevention           Atlanta, GA
# 13                               MobileDev Power     Atlanta, GA 30305
# 14                            Predictive Science         United States
# 15                               MobileDev Power     Atlanta, GA 30305
# 16                                Cox Automotive           Atlanta, GA
# 17                                    Home Depot     Atlanta, GA 30354
# 18                                           ICF           Atlanta, GA
# 19                                     Ashton212           Atlanta, GA
# 20                                     Honeywell           Atlanta, GA
# 21                                      GE Power           Atlanta, GA
# 22                              Northrop Grumman           Atlanta, GA
# 23                               Lockheed Martin    Marietta, GA 30063
# 24                   Eagle Medical Services, LLC           Atlanta, GA
# 25                        Cardlytics Corporation           Atlanta, GA
# 26                                        Turner     Atlanta, GA 30319
# 27                                     Honeywell           Atlanta, GA
# 28                                     Honeywell           Atlanta, GA
# 29                            Predictive Science         United States
# ...                                          ...                   ...
# 8866                        Amazon Corporate LLC         United States
# 8867                       Beckman Coulter, Inc.             Miami, FL
# 8868                        Amazon Corporate LLC         United States
# 8869                Altor BioScience Corporation           Miramar, FL
# 8870                          Predictive Science         United States
# 8871                                         HBI             Miami, FL
# 8872               Chicago Bridge & Iron Company       Miami Lakes, FL
# 8873                       Beckman Coulter, Inc.             Miami, FL
# 8874                               Wantman Group   Fort Lauderdale, FL
# 8875                                 Osthus Inc.  Plantation, FL 33324
# 8876                               Audible, Inc.         United States
# 8877                        Amazon Corporate LLC         United States
# 8878                        Amazon Corporate LLC         United States
# 8879                        Amazon Corporate LLC         United States
# 8880                   Amazon Web Services, Inc.         United States
# 8881                        Amazon Corporate LLC         United States
# 8882                       Beckman Coulter, Inc.             Miami, FL
# 8883                          Predictive Science         United States
# 8884                                         HBI             Miami, FL
# 8885               Chicago Bridge & Iron Company       Miami Lakes, FL
# 8886                       Beckman Coulter, Inc.             Miami, FL
# 8887                               Wantman Group   Fort Lauderdale, FL
# 8888                                 Osthus Inc.  Plantation, FL 33324
# 8889                               Audible, Inc.         United States
# 8890                        Amazon Corporate LLC         United States
# 8891                        Amazon Corporate LLC         United States
# 8892                        Amazon Corporate LLC         United States
# 8893                   Amazon Web Services, Inc.         United States
# 8894                        Amazon Corporate LLC         United States
# 8895                       Beckman Coulter, Inc.             Miami, FL
#
#                          Salary  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                   $90 an hour
# 5                   $67 an hour
# 6                          None
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12    $88,305 - $114,802 a year
# 13                         None
# 14                         None
# 15                         None
# 16                         None
# 17                         None
# 18                         None
# 19                         None
# 20                         None
# 21                         None
# 22                         None
# 23                         None
# 24                         None
# 25                         None
# 26                         None
# 27                         None
# 28                         None
# 29                         None
# ...                         ...
# 8866                       None
# 8867                       None
# 8868                       None
# 8869                       None
# 8870                       None
# 8871                       None
# 8872                       None
# 8873                       None
# 8874                       None
# 8875                       None
# 8876                       None
# 8877                       None
# 8878                       None
# 8879                       None
# 8880                       None
# 8881                       None
# 8882                       None
# 8883                       None
# 8884                       None
# 8885                       None
# 8886                       None
# 8887                       None
# 8888                       None
# 8889                       None
# 8890                       None
# 8891                       None
# 8892                       None
# 8893                       None
# 8894                       None
# 8895                       None
#
#                                                 Summary  \
# 0     This is a pioneering data scientist who will p...
# 1     Interprets problems and develops solutions to ...
# 2     Support and mentor data scientists. Minimum of...
# 3     Experience with healthcare-related data and fa...
# 4     Data Scientist- Big Data*. May write code to a...
# 5     Interacts with data scientists and industry ex...
# 6     Senior Data Scientist. Working closely with Pr...
# 7     The Google Cloud training team already develop...
# 8     Have experience with predictive modelling / da...
# 9     Uses analytical rigor and statistical methods,...
# 10    If you bring a deep focus and passion for a pa...
# 11    Perform data studies and data discovery around...
# 12    Whether we are protecting the American people ...
# 13    Authoritative quantitative analysis skills, pa...
# 14    This is a freelance data scientist position wh...
# 15    Build scalable predictive models based on data...
# 16    Description Cox Automotive is hiring a Data Sc...
# 17    Strong communication and data presentation ski...
# 18    Evaluate data errors and work to resolve data ...
# 19    The Important Stuff A leader in the payments i...
# 20    Advanced analytics/modelling projects, includi...
# 21    Ability to create and understand data models. ...
# 22    Perform data entry, cleaning, and analysis (bo...
# 23    Experience with full-scale pole model design, ...
# 24    Comfortable in collaborating with data scienti...
# 25    50 concurrent data scientists and analysts. Bu...
# 26    Has experience with SQL, R, SPSS, Tableau, Pow...
# 27    Work closely with data scientists and product ...
# 28    Support and mentor data scientists. Experience...
# 29    This is a freelance data scientist position wh...
# ...                                                 ...
# 8866  As a Principal, you will provide leadership to...
# 8867  Assist management in special assignments desig...
# 8868  Computer Science fundamentals in object-orient...
# 8869  Compile data to support/contribute to technica...
# 8870  This is a freelance data scientist position wh...
# 8871  Topic: Laboratory Testing Patterns/Profitabili...
# 8872  Collection and interpretation/evaluation of sc...
# 8873  Scientists use our life science research instr...
# 8874  Office work – including data management, prepa...
# 8875  To translate technical writing into commonly u...
# 8876  Do you enjoy working with Data Scientists to w...
# 8877  Experience with very large-scale data and the ...
# 8878  Are you interested in building data pipelines ...
# 8879  We specifically seek candidates who want to jo...
# 8880  Strong at applying data structures, algorithms...
# 8881  As a Principal, you will provide leadership to...
# 8882  Assist management in special assignments desig...
# 8883  This is a freelance data scientist position wh...
# 8884  Topic: Laboratory Testing Patterns/Profitabili...
# 8885  Collection and interpretation/evaluation of sc...
# 8886  Scientists use our life science research instr...
# 8887  Office work – including data management, prepa...
# 8888  To translate technical writing into commonly u...
# 8889  Do you enjoy working with Data Scientists to w...
# 8890  Experience with very large-scale data and the ...
# 8891  Are you interested in building data pipelines ...
# 8892  We specifically seek candidates who want to jo...
# 8893  Strong at applying data structures, algorithms...
# 8894  As a Principal, you will provide leadership to...
# 8895  Assist management in special assignments desig...
#
#                                                   Title
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                Principal Data Scientist - Atlanta, GA
# 3                                        Data Scientist
# 4                              Data Scientist- Big Data
# 5                                     Big Data Engineer
# 6                                    Sr. Data Scientist
# 7     Cloud Instructor (Big Data, Machine Learning),...
# 8                                        Data Scientist
# 9                                        Data Scientist
# 10                                   Sr. Data Scientist
# 11       AT&T Professional Data Scientist Alpharetta GA
# 12                                Statistician (Health)
# 13              Data Scientist With Predictive Modeling
# 14                                       Data Scientist
# 15              Data Scientist With Predictive Modeling
# 16                                       Data Scientist
# 17                                       DATA SCIENTIST
# 18                              Scientific Data Analyst
# 19                          Quantitative Analyst | #769
# 20                            Analytics DevOps Engineer
# 21                     IT Project Manager – Sourcing BI
# 22                          HAI Prevention Data Analyst
# 23                            Research Scientist Senior
# 24                                         Data Analyst
# 25                              Principal Data Engineer
# 26    Manager, Consumer Insights & Statistical Analysis
# 27                                   Big Data Architect
# 28               Principal Data Scientist - Atlanta, GA
# 29                                       Data Scientist
# ...                                                 ...
# 8866  Principal Data Scientist - Consumer Website- R...
# 8867                                      Accountant II
# 8868  Software Development Engineer – Emerging AWS M...
# 8869             Associate Scientist, Assay Development
# 8870                                     Data Scientist
# 8871  PhD Level Dissertation Researcher/Writer/Edito...
# 8872                            Environmental Scientist
# 8873                                    Manager Finance
# 8874           Environmental Scientist - Ft. Lauderdale
# 8875                    Scientific Domain Modeler (f/m)
# 8876  Software Development Engineer, Data Science- R...
# 8877  Principal Research Scientist- Relocation Oppor...
# 8878  Software Development Engineer, Big Data- Reloc...
# 8879  Software Development Engineer, Big Data Analyt...
# 8880  Software Development Engineer - AWS & Machine ...
# 8881  Principal Data Scientist - Consumer Website- R...
# 8882                                      Accountant II
# 8883                                     Data Scientist
# 8884  PhD Level Dissertation Researcher/Writer/Edito...
# 8885                            Environmental Scientist
# 8886                                    Manager Finance
# 8887           Environmental Scientist - Ft. Lauderdale
# 8888                    Scientific Domain Modeler (f/m)
# 8889  Software Development Engineer, Data Science- R...
# 8890  Principal Research Scientist- Relocation Oppor...
# 8891  Software Development Engineer, Big Data- Reloc...
# 8892  Software Development Engineer, Big Data Analyt...
# 8893  Software Development Engineer - AWS & Machine ...
# 8894  Principal Data Scientist - Consumer Website- R...
# 8895                                      Accountant II
#
# [8896 rows x 5 columns]

# %%
df.shape
# Out:
# (8896, 5)

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (293, 5)

# %%
df1.head(4)
# Out:
#                                        Company     Location  \
# 4                       Vision3 Solutions, Inc  Atlanta, GA
# 5                       eTek IT Services, Inc.  Atlanta, GA
# 12  Centers for Disease Control and Prevention  Atlanta, GA
# 37  Centers for Disease Control and Prevention  Atlanta, GA
#
#                        Salary  \
# 4                 $90 an hour
# 5                 $67 an hour
# 12  $88,305 - $114,802 a year
# 37   $74,260 - $96,538 a year
#
#                                               Summary  \
# 4   Data Scientist- Big Data*. May write code to a...
# 5   Interacts with data scientists and industry ex...
# 12  Whether we are protecting the American people ...
# 37  Identify and apply analytical methods, techniq...
#
#                        Title
# 4   Data Scientist- Big Data
# 5          Big Data Engineer
# 12     Statistician (Health)
# 37      Behavioral Scientist

# %%
len(results)
# Out:
# 8896

# %%
df1.dtypes
# Out:
# Company     object
# Location    object
# Salary      object
# Summary     object
# Title       object
# dtype: object

# %%
df2 = df1.drop_duplicates()

# %%
df2.shape
# Out:
# (219, 5)

# %%
df2
# Out:
#                                          Company  \
# 4                         Vision3 Solutions, Inc
# 5                         eTek IT Services, Inc.
# 12    Centers for Disease Control and Prevention
# 37    Centers for Disease Control and Prevention
# 48                           Analytic Recruiting
# 50                       Smith Hanley Associates
# 84                           Analytic Recruiting
# 98                                    Stackfolio
# 129                          Analytic Recruiting
# 130                             Emory University
# 144   Centers for Disease Control and Prevention
# 153                                         CSTE
# 172                            SearchBankingJobs
# 184                       eTek IT Services, Inc.
# 203                             Emory University
# 206                 DeKalb Workforce Development
# 214                         Synergy Search Group
# 279          Georgia Department of Public Health
# 321                     Klein Management Systems
# 424                             Emory University
# 425                  Interesse International Inc
# 755                                NewAgeSys,Inc
# 767                                   Driversiti
# 784                       Scienaptic Systems Inc
# 801                                 Wade & Wendy
# 813                                NewAgeSys,Inc
# 817                       Rang Technologies Inc.
# 857                                      Beeswax
# 859                                Real Staffing
# 861                     Recruiting Resources Co.
# ...                                          ...
# 6457     University of Washington Medical Center
# 6506                        LIBERTY MUTUAL GROUP
# 6508                    University of Washington
# 6625                    University of Washington
# 6626     University of Washington Medical Center
# 6659                             Harvey Nash USA
# 6667     University of Washington Medical Center
# 6712                        Hunter International
# 6732                        Hunter International
# 7454                             Tampa Bay Water
# 7456                       Moffitt Cancer Center
# 7459                 University of South Florida
# 7472                                     SSG LLC
# 7528                           SRG Life Sciences
# 8186                         University of Miami
# 8190                          The Bachrach Group
# 8191                                      Clarke
# 8201                         University of Miami
# 8209                         University of Miami
# 8210                         University of Miami
# 8223                         University of Miami
# 8234                         University of Miami
# 8236                     Smith Hanley Associates
# 8237                         University of Miami
# 8239                         University of Miami
# 8267                     Staffing Resource Group
# 8282                             Morgan Stephens
# 8337                         University of Miami
# 8344                         University of Miami
# 8345                         University of Miami
#
#                                       Location                      Salary  \
# 4                                  Atlanta, GA                 $90 an hour
# 5                                  Atlanta, GA                 $67 an hour
# 12                                 Atlanta, GA   $88,305 - $114,802 a year
# 37                                 Atlanta, GA    $74,260 - $96,538 a year
# 48                              Alpharetta, GA    $75,000 - $90,000 a year
# 50                                 Atlanta, GA   $75,000 - $100,000 a year
# 84                                 Atlanta, GA  $100,000 - $125,000 a year
# 98    Atlanta, GA 30308 (Old Fourth Ward area)              $80,000 a year
# 129                                Atlanta, GA   $70,000 - $145,000 a year
# 130                                Atlanta, GA              $85,500 a year
# 144                                Atlanta, GA   $88,305 - $114,802 a year
# 153                          Atlanta, GA 30341              $51,706 a year
# 172                                Atlanta, GA  $150,000 - $205,000 a year
# 184                                Atlanta, GA                 $67 an hour
# 203                                Atlanta, GA              $69,900 a year
# 206                                Decatur, GA           $13 - $18 an hour
# 214                                Atlanta, GA              $80,000 a year
# 279                                Atlanta, GA              $24,000 a year
# 321                                Atlanta, GA                 $57 an hour
# 424                                Atlanta, GA              $66,700 a year
# 425                                Atlanta, GA    $60,000 - $70,000 a year
# 755                             Parsippany, NJ              $55,000 a year
# 767                          Rochelle Park, NJ             $100,000 a year
# 784                               New York, NY             $100,000 a year
# 801                               New York, NY   $80,000 - $120,000 a year
# 813                             Kenilworth, NJ              $50,000 a year
# 817                       Piscataway, NJ 08854              $80,000 a year
# 857                               New York, NY  $130,000 - $165,000 a year
# 859                                  Union, NJ             $166,400 a year
# 861                               Whippany, NJ              $76.57 an hour
# ...                                        ...                         ...
# 6457                               Seattle, WA     $2,623 - $3,644 a month
# 6506                               Seattle, WA  $109,900 - $126,100 a year
# 6508                               Seattle, WA     $4,495 - $6,433 a month
# 6625                               Seattle, WA     $2,417 - $3,192 a month
# 6626                               Seattle, WA     $4,319 - $6,183 a month
# 6659                               Seattle, WA  $120,000 - $130,000 a year
# 6667                               Seattle, WA     $3,007 - $4,008 a month
# 6712                             Cleveland, OH    $60,000 - $80,000 a year
# 6732                             Cleveland, OH    $50,000 - $70,000 a year
# 7454                      Clearwater, FL 33761    $56,963 - $93,989 a year
# 7456                           Tampa, FL 33612             $100,000 a year
# 7459                                 Tampa, FL    $31,000 - $38,000 a year
# 7472                            Clearwater, FL             $100,000 a year
# 7528                      Saint Petersburg, FL                 $32 an hour
# 8186                          Coral Gables, FL    $53,900 - $65,000 a year
# 8190                           Miami Lakes, FL              $80,000 a year
# 8191                       Fort Lauderdale, FL           $10 - $12 an hour
# 8201                          Coral Gables, FL   $77,600 - $108,600 a year
# 8209                          Coral Gables, FL    $32,900 - $59,100 a year
# 8210                          Coral Gables, FL    $40,000 - $72,000 a year
# 8223                          Coral Gables, FL   $77,600 - $139,600 a year
# 8234                          Coral Gables, FL    $38,750 - $51,000 a year
# 8236                                 Miami, FL    $75,000 - $95,000 a year
# 8237                          Coral Gables, FL              $32,900 a year
# 8239                          Coral Gables, FL    $27,400 - $49,400 a year
# 8267                           Miami, FL 33186                 $23 an hour
# 8282                                 Miami, FL    $75,000 - $85,000 a year
# 8337                          Coral Gables, FL    $53,900 - $96,900 a year
# 8344                          Coral Gables, FL    $38,750 - $62,000 a year
# 8345                          Coral Gables, FL    $40,000 - $72,000 a year
#
#                                                 Summary  \
# 4     Data Scientist- Big Data*. May write code to a...
# 5     Interacts with data scientists and industry ex...
# 12    Whether we are protecting the American people ...
# 37    Identify and apply analytical methods, techniq...
# 48    Junior Data Scientist sought by Fortune 500 co...
# 50    -Post degree business based experience doing d...
# 84    Python, data mining, data science; The data Sc...
# 98    We are looking for a bright and experienced da...
# 129   Data Scientist, Supply Chain sought by Fortune...
# 130   Staff Scientists will have leadership responsi...
# 144   Assess data for completeness, accuracy, and qu...
# 153   Skills with developing and presenting epidemio...
# 172   The client is looking for talented individuals...
# 184   Yes// Translate data needs into Big Data solut...
# 203   The Medical Image Analysis Scientist, works wi...
# 206    Develop and maintains accurate field data an...
# 214   Duties will include data conversion from multi...
# 279   Under broad supervision, assists technicians a...
# 321   Client is looking for Recruiters who have plac...
# 424   Responsible for post award processing of grant...
# 425   Estimate numerical data; Must see through the ...
# 755   Working knowledge of both computer and/or data...
# 767   Data Plotting - Visualization libraries such a...
# 784   We are looking for an energetic and experience...
# 801   Our Data Scientist will integrate data from we...
# 813   Analysis and interpretation data. Candidate mu...
# 817   Experience in data visualization and presentat...
# 857   A minimum of 5 years experience in Machine lea...
# 859   Experience in performing reviews of clinical t...
# 861   The primary responsibility of the Lead Statist...
# ...                                                 ...
# 6457  Knowledge of UB, HCFA, ADA and other utilized ...
# 6506  We are searching for a highly motivated data s...
# 6508  Enter patient and Quality Control Data into th...
# 6625  Demonstrate the ability to input accurate data...
# 6626  One year of experience as a Medical Laboratory...
# 6659  We are looking for talented, ambitious enginee...
# 6667  Maintains necessary documentation regarding an...
# 6712  Review data for technical content and good rec...
# 6732  QC Associate Scientist. Review data for techni...
# 7454  In addition, the Water Quality Scientist:. Str...
# 7456  Alan List, an active physician scientist. The ...
# 7459  5033 / Biological Scientist. Data Interpretati...
# 7472  Advanced data mining:. Experience working with...
# 7528  Audits and verifies results, including but not...
# 8186  This position interacts with an established gr...
# 8190  Experience working with a large amount of data...
# 8191  Conduct all assigned field and laboratory expe...
# 8201  This position is responsible for planning, imp...
# 8209  Ability to analyze data and formulate conclusi...
# 8210  The University of Miami is considered among th...
# 8223  The Scientist will assist core users in prepar...
# 8234  The University of Miami is considered among th...
# 8236  Conduct analysis of business data to present i...
# 8237  Conduct routine data checks to ensure data int...
# 8239  Duties may include, but will not be limited to...
# 8267  Senior Scientist, Research Scientist, Analytic...
# 8282  Looking for a Legal Librarian that will be res...
# 8337  Expertise in basic statistical analytic techni...
# 8344  Experience with data management and statistica...
# 8345  The University of Miami is considered among th...
#
#                                               Title
# 4                          Data Scientist- Big Data
# 5                                 Big Data Engineer
# 12                            Statistician (Health)
# 37                             Behavioral Scientist
# 48                            Junior Data Scientist
# 50                           Marketing Statistician
# 84                            Senior Data Scientist
# 98                              Lead Data Scientist
# 129                   Data Scientist - Supply Chain
# 130                 Staff Scientist (Goldsmith Lab)
# 144                           Statistician (Health)
# 153                      Associate Research Analyst
# 172                       Lead Quantitative Analyst
# 184                               Big Data Engineer
# 203                    Scientist, Med Imag Analysis
# 206                          Engineering Technician
# 214     Audit Snr (Banking) - Data Analysis 60K-80K
# 279                               Laboratory Aide 3
# 321                     Recruiter III (Software/IT)
# 424            Sponsored Research Financial Analyst
# 425                 Market Research & Sales Analyst
# 755                           Scientist II (Pfizer)
# 767       Full-Stack Dev Data Viz - Pythonic Design
# 784                                  Data Scientist
# 801            Wade & Wendy_Data Scientist/Engineer
# 813                 Biochemist (Scientist II) Merck
# 817                                  Data Scientist
# 857                  Senior / Director Data Science
# 859                     Clinical Research Scientist
# 861                       Statistical Analyst (SAS)
# ...                                             ...
# 6457        PATIENT FINANCIAL SERVICES SPECIALIST 2
# 6506               Assistant Director, Data Science
# 6508                 MEDICAL LABORATORY SCIENTIST 1
# 6625                          STOCKROOM ATTENDANT 2
# 6626      MEDICAL LABORATORY SCIENTIST 1 OR TRAINEE
# 6659                   Data Scientist - Engineering
# 6667                      RECORDS CENTER SPECIALIST
# 6712                                GC-MS Scientist
# 6732                      Quality Control Scientist
# 7454                        Water Quality Scientist
# 7456  Associate Center Director, Population Science
# 7459                           Biological Scientist
# 7472                       Statistical Data Analyst
# 7528          QC Laboratory investigator/ scientist
# 8186     Assistant Scientist/Postdoctoral Associate
# 8190                 Quantitative Financial Analyst
# 8191      Environmental Science Bioassay Internship
# 8201          Lead Research Analyst (Biostatistics)
# 8209                               Research Analyst
# 8210        Sr. Research Analyst / Pre-award Grants
# 8223                                      Scientist
# 8234  Financial Analyst (Clinical Research Revenue)
# 8236        Statistical Operations Research Analyst
# 8237                         Statistical Programmer
# 8239     (Temporary) Research Laboratory Technician
# 8267                                   QC Scientist
# 8282                     Librarian Research Analyst
# 8337                            Assistant Scientist
# 8344                   (Temporary) Research Analyst
# 8345                           Sr. Research Analyst
#
# [219 rows x 5 columns]

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
# combine data into dictionaries
# rows = []
# for result in results:
#     if result:
#         row = {'location': }

# # create dataframe
# import pandas as pd

# %% [markdown]
# Lastly, we need to clean up salary data.
#
# 1. Only a small number of the scraped results have salary information - only these will be used for modeling.
# 1. Some of the salaries are not yearly but hourly or weekly, these will not be useful to us for now
# 1. Some of the entries may be duplicated
# 1. The salaries are given as text and usually with ranges.
#
# #### Find the entries with annual salary entries, by filtering the entries without salaries or salaries that are not yearly (filter those that refer to hour or week). Also, remove duplicate entries

# %%
# Filter to only the rows that have salary entries

# Remove duplicates

# Filter out salary entries referring to week, hour or month
df2 = df2[~(df2.Salary.astype('str').str.contains('hour'))]
df2 = df2[~(df2.Salary.astype('str').str.contains('month'))]
df2 = df2[~(df2.Salary.astype('str').str.contains('week'))]

df2.shape
# Out:
# (175, 5)

# %%
df2
# Out:
#                                          Company  \
# 12    Centers for Disease Control and Prevention
# 37    Centers for Disease Control and Prevention
# 48                           Analytic Recruiting
# 50                       Smith Hanley Associates
# 84                           Analytic Recruiting
# 98                                    Stackfolio
# 129                          Analytic Recruiting
# 130                             Emory University
# 144   Centers for Disease Control and Prevention
# 153                                         CSTE
# 172                            SearchBankingJobs
# 203                             Emory University
# 214                         Synergy Search Group
# 279          Georgia Department of Public Health
# 424                             Emory University
# 425                  Interesse International Inc
# 755                                NewAgeSys,Inc
# 767                                   Driversiti
# 784                       Scienaptic Systems Inc
# 801                                 Wade & Wendy
# 813                                NewAgeSys,Inc
# 817                       Rang Technologies Inc.
# 857                                      Beeswax
# 859                                Real Staffing
# 877                                Harris Allied
# 908                                      Harnham
# 969                               Selby Jennings
# 984                                      Harnham
# 1010                                     Averity
# 1082                                     Averity
# ...                                          ...
# 6025                      Philanthropy Northwest
# 6055                       Dynamic Staffing Inc.
# 6132                                   HERO.Jobs
# 6162                       Smith Arnold Partners
# 6205                            All-In Analytics
# 6236            Cutting Edge Medical Diagnostics
# 6328                         State of Washington
# 6427                       Lighthouse Recruiting
# 6506                        LIBERTY MUTUAL GROUP
# 6659                             Harvey Nash USA
# 6712                        Hunter International
# 6732                        Hunter International
# 7454                             Tampa Bay Water
# 7456                       Moffitt Cancer Center
# 7459                 University of South Florida
# 7472                                     SSG LLC
# 8186                         University of Miami
# 8190                          The Bachrach Group
# 8201                         University of Miami
# 8209                         University of Miami
# 8210                         University of Miami
# 8223                         University of Miami
# 8234                         University of Miami
# 8236                     Smith Hanley Associates
# 8237                         University of Miami
# 8239                         University of Miami
# 8282                             Morgan Stephens
# 8337                         University of Miami
# 8344                         University of Miami
# 8345                         University of Miami
#
#                                       Location                      Salary  \
# 12                                 Atlanta, GA   $88,305 - $114,802 a year
# 37                                 Atlanta, GA    $74,260 - $96,538 a year
# 48                              Alpharetta, GA    $75,000 - $90,000 a year
# 50                                 Atlanta, GA   $75,000 - $100,000 a year
# 84                                 Atlanta, GA  $100,000 - $125,000 a year
# 98    Atlanta, GA 30308 (Old Fourth Ward area)              $80,000 a year
# 129                                Atlanta, GA   $70,000 - $145,000 a year
# 130                                Atlanta, GA              $85,500 a year
# 144                                Atlanta, GA   $88,305 - $114,802 a year
# 153                          Atlanta, GA 30341              $51,706 a year
# 172                                Atlanta, GA  $150,000 - $205,000 a year
# 203                                Atlanta, GA              $69,900 a year
# 214                                Atlanta, GA              $80,000 a year
# 279                                Atlanta, GA              $24,000 a year
# 424                                Atlanta, GA              $66,700 a year
# 425                                Atlanta, GA    $60,000 - $70,000 a year
# 755                             Parsippany, NJ              $55,000 a year
# 767                          Rochelle Park, NJ             $100,000 a year
# 784                               New York, NY             $100,000 a year
# 801                               New York, NY   $80,000 - $120,000 a year
# 813                             Kenilworth, NJ              $50,000 a year
# 817                       Piscataway, NJ 08854              $80,000 a year
# 857                               New York, NY  $130,000 - $165,000 a year
# 859                                  Union, NJ             $166,400 a year
# 877          New York, NY 10018 (Clinton area)             $140,000 a year
# 908                               New York, NY             $170,000 a year
# 969          New York, NY 10167 (Midtown area)  $200,000 - $250,000 a year
# 984                               New York, NY             $200,000 a year
# 1010                              New York, NY  $125,000 - $175,000 a year
# 1082                              New York, NY   $90,000 - $100,000 a year
# ...                                        ...                         ...
# 6025         Seattle, WA 98121 (Belltown area)    $50,000 - $60,000 a year
# 6055                               Seattle, WA             $125,000 a year
# 6132                               Seattle, WA             $160,000 a year
# 6162                               Seattle, WA    $50,000 - $65,000 a year
# 6205                               Seattle, WA  $150,000 - $175,000 a year
# 6236                               Seattle, WA             $140,000 a year
# 6328                              Bellevue, WA    $48,060 - $63,036 a year
# 6427                               Seattle, WA   $90,000 - $100,000 a year
# 6506                               Seattle, WA  $109,900 - $126,100 a year
# 6659                               Seattle, WA  $120,000 - $130,000 a year
# 6712                             Cleveland, OH    $60,000 - $80,000 a year
# 6732                             Cleveland, OH    $50,000 - $70,000 a year
# 7454                      Clearwater, FL 33761    $56,963 - $93,989 a year
# 7456                           Tampa, FL 33612             $100,000 a year
# 7459                                 Tampa, FL    $31,000 - $38,000 a year
# 7472                            Clearwater, FL             $100,000 a year
# 8186                          Coral Gables, FL    $53,900 - $65,000 a year
# 8190                           Miami Lakes, FL              $80,000 a year
# 8201                          Coral Gables, FL   $77,600 - $108,600 a year
# 8209                          Coral Gables, FL    $32,900 - $59,100 a year
# 8210                          Coral Gables, FL    $40,000 - $72,000 a year
# 8223                          Coral Gables, FL   $77,600 - $139,600 a year
# 8234                          Coral Gables, FL    $38,750 - $51,000 a year
# 8236                                 Miami, FL    $75,000 - $95,000 a year
# 8237                          Coral Gables, FL              $32,900 a year
# 8239                          Coral Gables, FL    $27,400 - $49,400 a year
# 8282                                 Miami, FL    $75,000 - $85,000 a year
# 8337                          Coral Gables, FL    $53,900 - $96,900 a year
# 8344                          Coral Gables, FL    $38,750 - $62,000 a year
# 8345                          Coral Gables, FL    $40,000 - $72,000 a year
#
#                                                 Summary  \
# 12    Whether we are protecting the American people ...
# 37    Identify and apply analytical methods, techniq...
# 48    Junior Data Scientist sought by Fortune 500 co...
# 50    -Post degree business based experience doing d...
# 84    Python, data mining, data science; The data Sc...
# 98    We are looking for a bright and experienced da...
# 129   Data Scientist, Supply Chain sought by Fortune...
# 130   Staff Scientists will have leadership responsi...
# 144   Assess data for completeness, accuracy, and qu...
# 153   Skills with developing and presenting epidemio...
# 172   The client is looking for talented individuals...
# 203   The Medical Image Analysis Scientist, works wi...
# 214   Duties will include data conversion from multi...
# 279   Under broad supervision, assists technicians a...
# 424   Responsible for post award processing of grant...
# 425   Estimate numerical data; Must see through the ...
# 755   Working knowledge of both computer and/or data...
# 767   Data Plotting - Visualization libraries such a...
# 784   We are looking for an energetic and experience...
# 801   Our Data Scientist will integrate data from we...
# 813   Analysis and interpretation data. Candidate mu...
# 817   Experience in data visualization and presentat...
# 857   A minimum of 5 years experience in Machine lea...
# 859   Experience in performing reviews of clinical t...
# 877   Very high profile- you will be the point perso...
# 908   Senior Data Scientist - Bio-tech. Senior Data ...
# 969   Experience working with and managing large dat...
# 984   Senior Data Scientist. However this opportunit...
# 1010  Our data science needs are growing quickly, an...
# 1082  Are you a Mid-level Data Scientist looking to ...
# ...                                                 ...
# 6025  Conduct research and provide data analysis in ...
# 6055  Exposure to big data systems (Hadoop, HBASE, H...
# 6132  Build big data, machine learning applications ...
# 6162  Growing international custom research supplier...
# 6205  Working with a team of Analysts, Software Deve...
# 6236  Data and image analysis using advanced statist...
# 6328  Performing field surveys or studies, 2) respon...
# 6427  Join our Medical Laboratory Scientists Groups:...
# 6506  We are searching for a highly motivated data s...
# 6659  We are looking for talented, ambitious enginee...
# 6712  Review data for technical content and good rec...
# 6732  QC Associate Scientist. Review data for techni...
# 7454  In addition, the Water Quality Scientist:. Str...
# 7456  Alan List, an active physician scientist. The ...
# 7459  5033 / Biological Scientist. Data Interpretati...
# 7472  Advanced data mining:. Experience working with...
# 8186  This position interacts with an established gr...
# 8190  Experience working with a large amount of data...
# 8201  This position is responsible for planning, imp...
# 8209  Ability to analyze data and formulate conclusi...
# 8210  The University of Miami is considered among th...
# 8223  The Scientist will assist core users in prepar...
# 8234  The University of Miami is considered among th...
# 8236  Conduct analysis of business data to present i...
# 8237  Conduct routine data checks to ensure data int...
# 8239  Duties may include, but will not be limited to...
# 8282  Looking for a Legal Librarian that will be res...
# 8337  Expertise in basic statistical analytic techni...
# 8344  Experience with data management and statistica...
# 8345  The University of Miami is considered among th...
#
#                                                   Title
# 12                                Statistician (Health)
# 37                                 Behavioral Scientist
# 48                                Junior Data Scientist
# 50                               Marketing Statistician
# 84                                Senior Data Scientist
# 98                                  Lead Data Scientist
# 129                       Data Scientist - Supply Chain
# 130                     Staff Scientist (Goldsmith Lab)
# 144                               Statistician (Health)
# 153                          Associate Research Analyst
# 172                           Lead Quantitative Analyst
# 203                        Scientist, Med Imag Analysis
# 214         Audit Snr (Banking) - Data Analysis 60K-80K
# 279                                   Laboratory Aide 3
# 424                Sponsored Research Financial Analyst
# 425                     Market Research & Sales Analyst
# 755                               Scientist II (Pfizer)
# 767           Full-Stack Dev Data Viz - Pythonic Design
# 784                                      Data Scientist
# 801                Wade & Wendy_Data Scientist/Engineer
# 813                     Biochemist (Scientist II) Merck
# 817                                      Data Scientist
# 857                      Senior / Director Data Science
# 859                         Clinical Research Scientist
# 877                  Quantitative Research/Data Analyst
# 908                    Senior Data Scientist - Bio-tech
# 969          Quantitative Researcher – Machine Learning
# 984                               Senior Data Scientist
# 1010                              Senior Data Scientist
# 1082    Mid-level Data Scientist For Top Travel Company
# ...                                                 ...
# 6025              Research Analyst, The Giving Practice
# 6055                   Data Scientist-Software Engineer
# 6132    Machine Learning Engineer - Big Data, Python, R
# 6162                                   Research Analyst
# 6205                          Sr. Global Device Manager
# 6236  Sr. Data Scientist / Machine Learning (In-vitr...
# 6328             TMDL Lead (Environmental Specialist 4)
# 6427                         Variant Scientist (Remote)
# 6506                   Assistant Director, Data Science
# 6659                       Data Scientist - Engineering
# 6712                                    GC-MS Scientist
# 6732                          Quality Control Scientist
# 7454                            Water Quality Scientist
# 7456      Associate Center Director, Population Science
# 7459                               Biological Scientist
# 7472                           Statistical Data Analyst
# 8186         Assistant Scientist/Postdoctoral Associate
# 8190                     Quantitative Financial Analyst
# 8201              Lead Research Analyst (Biostatistics)
# 8209                                   Research Analyst
# 8210            Sr. Research Analyst / Pre-award Grants
# 8223                                          Scientist
# 8234      Financial Analyst (Clinical Research Revenue)
# 8236            Statistical Operations Research Analyst
# 8237                             Statistical Programmer
# 8239         (Temporary) Research Laboratory Technician
# 8282                         Librarian Research Analyst
# 8337                                Assistant Scientist
# 8344                       (Temporary) Research Analyst
# 8345                               Sr. Research Analyst
#
# [175 rows x 5 columns]

# %% [markdown]
#  Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import re
import numpy as np
def extract_salary_average(salary_string):
    regex = r'\$([0-9]+,[0-9]+)'   
    matches = re.findall(regex, salary_string)
    return np.mean([float(salary.replace(',', '')) for salary in matches ])
    return matches

# %%
l1 = []
for i in df2["Salary"]:
    a = extract_salary_average(i)
    l1.append(a)
    
len(l1 ) 
df2["Salary"] = l1

# %%
df2.head(2)
# Out:
#                                        Company     Location    Salary  \
# 12  Centers for Disease Control and Prevention  Atlanta, GA  101553.5
# 37  Centers for Disease Control and Prevention  Atlanta, GA   85399.0
#
#                                               Summary                  Title  \
# 12  Whether we are protecting the American people ...  Statistician (Health)
# 37  Identify and apply analytical methods, techniq...   Behavioral Scientist
#
#     Salary_class
# 12             1
# 37             1

# %%
df2.shape
# Out:
# (175, 6)

# %%
df2["Salary"] = df2["Salary"].astype(float)

# %%
median_Salary = df2["Salary"].median()

# %%
type(median_Salary)
# Out:
# float

# %%
df2.dtypes
# Out:
# Company          object
# Location         object
# Salary          float64
# Summary          object
# Title            object
# Salary_class      int64
# dtype: object

# %%
df2["Salary_class"] = df2["Salary"].map(lambda x: 1 if x>=median_Salary else 0)

# %%
df2
# Out:
#                                          Company  \
# 12    Centers for Disease Control and Prevention
# 37    Centers for Disease Control and Prevention
# 48                           Analytic Recruiting
# 50                       Smith Hanley Associates
# 84                           Analytic Recruiting
# 98                                    Stackfolio
# 129                          Analytic Recruiting
# 130                             Emory University
# 144   Centers for Disease Control and Prevention
# 153                                         CSTE
# 172                            SearchBankingJobs
# 203                             Emory University
# 214                         Synergy Search Group
# 279          Georgia Department of Public Health
# 424                             Emory University
# 425                  Interesse International Inc
# 755                                NewAgeSys,Inc
# 767                                   Driversiti
# 784                       Scienaptic Systems Inc
# 801                                 Wade & Wendy
# 813                                NewAgeSys,Inc
# 817                       Rang Technologies Inc.
# 857                                      Beeswax
# 859                                Real Staffing
# 877                                Harris Allied
# 908                                      Harnham
# 969                               Selby Jennings
# 984                                      Harnham
# 1010                                     Averity
# 1082                                     Averity
# ...                                          ...
# 6025                      Philanthropy Northwest
# 6055                       Dynamic Staffing Inc.
# 6132                                   HERO.Jobs
# 6162                       Smith Arnold Partners
# 6205                            All-In Analytics
# 6236            Cutting Edge Medical Diagnostics
# 6328                         State of Washington
# 6427                       Lighthouse Recruiting
# 6506                        LIBERTY MUTUAL GROUP
# 6659                             Harvey Nash USA
# 6712                        Hunter International
# 6732                        Hunter International
# 7454                             Tampa Bay Water
# 7456                       Moffitt Cancer Center
# 7459                 University of South Florida
# 7472                                     SSG LLC
# 8186                         University of Miami
# 8190                          The Bachrach Group
# 8201                         University of Miami
# 8209                         University of Miami
# 8210                         University of Miami
# 8223                         University of Miami
# 8234                         University of Miami
# 8236                     Smith Hanley Associates
# 8237                         University of Miami
# 8239                         University of Miami
# 8282                             Morgan Stephens
# 8337                         University of Miami
# 8344                         University of Miami
# 8345                         University of Miami
#
#                                       Location    Salary  \
# 12                                 Atlanta, GA  101553.5
# 37                                 Atlanta, GA   85399.0
# 48                              Alpharetta, GA   82500.0
# 50                                 Atlanta, GA   87500.0
# 84                                 Atlanta, GA  112500.0
# 98    Atlanta, GA 30308 (Old Fourth Ward area)   80000.0
# 129                                Atlanta, GA  107500.0
# 130                                Atlanta, GA   85500.0
# 144                                Atlanta, GA  101553.5
# 153                          Atlanta, GA 30341   51706.0
# 172                                Atlanta, GA  177500.0
# 203                                Atlanta, GA   69900.0
# 214                                Atlanta, GA   80000.0
# 279                                Atlanta, GA   24000.0
# 424                                Atlanta, GA   66700.0
# 425                                Atlanta, GA   65000.0
# 755                             Parsippany, NJ   55000.0
# 767                          Rochelle Park, NJ  100000.0
# 784                               New York, NY  100000.0
# 801                               New York, NY  100000.0
# 813                             Kenilworth, NJ   50000.0
# 817                       Piscataway, NJ 08854   80000.0
# 857                               New York, NY  147500.0
# 859                                  Union, NJ  166400.0
# 877          New York, NY 10018 (Clinton area)  140000.0
# 908                               New York, NY  170000.0
# 969          New York, NY 10167 (Midtown area)  225000.0
# 984                               New York, NY  200000.0
# 1010                              New York, NY  150000.0
# 1082                              New York, NY   95000.0
# ...                                        ...       ...
# 6025         Seattle, WA 98121 (Belltown area)   55000.0
# 6055                               Seattle, WA  125000.0
# 6132                               Seattle, WA  160000.0
# 6162                               Seattle, WA   57500.0
# 6205                               Seattle, WA  162500.0
# 6236                               Seattle, WA  140000.0
# 6328                              Bellevue, WA   55548.0
# 6427                               Seattle, WA   95000.0
# 6506                               Seattle, WA  118000.0
# 6659                               Seattle, WA  125000.0
# 6712                             Cleveland, OH   70000.0
# 6732                             Cleveland, OH   60000.0
# 7454                      Clearwater, FL 33761   75476.0
# 7456                           Tampa, FL 33612  100000.0
# 7459                                 Tampa, FL   34500.0
# 7472                            Clearwater, FL  100000.0
# 8186                          Coral Gables, FL   59450.0
# 8190                           Miami Lakes, FL   80000.0
# 8201                          Coral Gables, FL   93100.0
# 8209                          Coral Gables, FL   46000.0
# 8210                          Coral Gables, FL   56000.0
# 8223                          Coral Gables, FL  108600.0
# 8234                          Coral Gables, FL   44875.0
# 8236                                 Miami, FL   85000.0
# 8237                          Coral Gables, FL   32900.0
# 8239                          Coral Gables, FL   38400.0
# 8282                                 Miami, FL   80000.0
# 8337                          Coral Gables, FL   75400.0
# 8344                          Coral Gables, FL   50375.0
# 8345                          Coral Gables, FL   56000.0
#
#                                                 Summary  \
# 12    Whether we are protecting the American people ...
# 37    Identify and apply analytical methods, techniq...
# 48    Junior Data Scientist sought by Fortune 500 co...
# 50    -Post degree business based experience doing d...
# 84    Python, data mining, data science; The data Sc...
# 98    We are looking for a bright and experienced da...
# 129   Data Scientist, Supply Chain sought by Fortune...
# 130   Staff Scientists will have leadership responsi...
# 144   Assess data for completeness, accuracy, and qu...
# 153   Skills with developing and presenting epidemio...
# 172   The client is looking for talented individuals...
# 203   The Medical Image Analysis Scientist, works wi...
# 214   Duties will include data conversion from multi...
# 279   Under broad supervision, assists technicians a...
# 424   Responsible for post award processing of grant...
# 425   Estimate numerical data; Must see through the ...
# 755   Working knowledge of both computer and/or data...
# 767   Data Plotting - Visualization libraries such a...
# 784   We are looking for an energetic and experience...
# 801   Our Data Scientist will integrate data from we...
# 813   Analysis and interpretation data. Candidate mu...
# 817   Experience in data visualization and presentat...
# 857   A minimum of 5 years experience in Machine lea...
# 859   Experience in performing reviews of clinical t...
# 877   Very high profile- you will be the point perso...
# 908   Senior Data Scientist - Bio-tech. Senior Data ...
# 969   Experience working with and managing large dat...
# 984   Senior Data Scientist. However this opportunit...
# 1010  Our data science needs are growing quickly, an...
# 1082  Are you a Mid-level Data Scientist looking to ...
# ...                                                 ...
# 6025  Conduct research and provide data analysis in ...
# 6055  Exposure to big data systems (Hadoop, HBASE, H...
# 6132  Build big data, machine learning applications ...
# 6162  Growing international custom research supplier...
# 6205  Working with a team of Analysts, Software Deve...
# 6236  Data and image analysis using advanced statist...
# 6328  Performing field surveys or studies, 2) respon...
# 6427  Join our Medical Laboratory Scientists Groups:...
# 6506  We are searching for a highly motivated data s...
# 6659  We are looking for talented, ambitious enginee...
# 6712  Review data for technical content and good rec...
# 6732  QC Associate Scientist. Review data for techni...
# 7454  In addition, the Water Quality Scientist:. Str...
# 7456  Alan List, an active physician scientist. The ...
# 7459  5033 / Biological Scientist. Data Interpretati...
# 7472  Advanced data mining:. Experience working with...
# 8186  This position interacts with an established gr...
# 8190  Experience working with a large amount of data...
# 8201  This position is responsible for planning, imp...
# 8209  Ability to analyze data and formulate conclusi...
# 8210  The University of Miami is considered among th...
# 8223  The Scientist will assist core users in prepar...
# 8234  The University of Miami is considered among th...
# 8236  Conduct analysis of business data to present i...
# 8237  Conduct routine data checks to ensure data int...
# 8239  Duties may include, but will not be limited to...
# 8282  Looking for a Legal Librarian that will be res...
# 8337  Expertise in basic statistical analytic techni...
# 8344  Experience with data management and statistica...
# 8345  The University of Miami is considered among th...
#
#                                                   Title  Salary_class
# 12                                Statistician (Health)             1
# 37                                 Behavioral Scientist             0
# 48                                Junior Data Scientist             0
# 50                               Marketing Statistician             0
# 84                                Senior Data Scientist             1
# 98                                  Lead Data Scientist             0
# 129                       Data Scientist - Supply Chain             1
# 130                     Staff Scientist (Goldsmith Lab)             0
# 144                               Statistician (Health)             1
# 153                          Associate Research Analyst             0
# 172                           Lead Quantitative Analyst             1
# 203                        Scientist, Med Imag Analysis             0
# 214         Audit Snr (Banking) - Data Analysis 60K-80K             0
# 279                                   Laboratory Aide 3             0
# 424                Sponsored Research Financial Analyst             0
# 425                     Market Research & Sales Analyst             0
# 755                               Scientist II (Pfizer)             0
# 767           Full-Stack Dev Data Viz - Pythonic Design             1
# 784                                      Data Scientist             1
# 801                Wade & Wendy_Data Scientist/Engineer             1
# 813                     Biochemist (Scientist II) Merck             0
# 817                                      Data Scientist             0
# 857                      Senior / Director Data Science             1
# 859                         Clinical Research Scientist             1
# 877                  Quantitative Research/Data Analyst             1
# 908                    Senior Data Scientist - Bio-tech             1
# 969          Quantitative Researcher – Machine Learning             1
# 984                               Senior Data Scientist             1
# 1010                              Senior Data Scientist             1
# 1082    Mid-level Data Scientist For Top Travel Company             0
# ...                                                 ...           ...
# 6025              Research Analyst, The Giving Practice             0
# 6055                   Data Scientist-Software Engineer             1
# 6132    Machine Learning Engineer - Big Data, Python, R             1
# 6162                                   Research Analyst             0
# 6205                          Sr. Global Device Manager             1
# 6236  Sr. Data Scientist / Machine Learning (In-vitr...             1
# 6328             TMDL Lead (Environmental Specialist 4)             0
# 6427                         Variant Scientist (Remote)             0
# 6506                   Assistant Director, Data Science             1
# 6659                       Data Scientist - Engineering             1
# 6712                                    GC-MS Scientist             0
# 6732                          Quality Control Scientist             0
# 7454                            Water Quality Scientist             0
# 7456      Associate Center Director, Population Science             1
# 7459                               Biological Scientist             0
# 7472                           Statistical Data Analyst             1
# 8186         Assistant Scientist/Postdoctoral Associate             0
# 8190                     Quantitative Financial Analyst             0
# 8201              Lead Research Analyst (Biostatistics)             0
# 8209                                   Research Analyst             0
# 8210            Sr. Research Analyst / Pre-award Grants             0
# 8223                                          Scientist             1
# 8234      Financial Analyst (Clinical Research Revenue)             0
# 8236            Statistical Operations Research Analyst             0
# 8237                             Statistical Programmer             0
# 8239         (Temporary) Research Laboratory Technician             0
# 8282                         Librarian Research Analyst             0
# 8337                                Assistant Scientist             0
# 8344                       (Temporary) Research Analyst             0
# 8345                               Sr. Research Analyst             0
#
# [175 rows x 6 columns]

# %%
#salary_data['high_salary'] = salary_data['salary'].map(lambda x: 1 if x >= medianSalary else 0)

# %%
# use '.map' to transform salary to new feature
# Out:
#   File "<ipython-input-57-8b0a17d9170d>", line 3
#     df2["Salary"]
#       ^
# SyntaxError: invalid syntax

# %%
# save scraped results as a CSV for Tableau/external viz
df2.to_csv('indeed salary_file',sep='\t', encoding='utf-8')

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %%
# load in the the data of scraped salaries

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
# calculate median and create feature with 1 as high salary

# %% [markdown]
# ### Q: What is the baseline accuracy for this model?

# %% [markdown]
# It is 50% if we guess randomly, half the salaries will be below the median and half will be above.

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
# create statsmodel and summary
import statsmodels.formula.api as sm

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' or 'Manager' is in the title
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
# create senior, director, and manager dummies
salary_data['is_senior'] = salary_data['title'].str.contains('Senior').astype(int) # example

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
# scale, (patsy optional), and fit
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from patsy import dmatrix

scaler = StandardScaler()
model = LogisticRegression(penalty = 'l2', C=0.1)

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
from sklearn.cross_validation import cross_val_score

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']: # example

# %% [markdown]
# ### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
model = LogisticRegression(penalty = 'l1', C=1.0)

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:

# %%
model.fit(X_scaled, y)

df = pd.DataFrame({'features' : X.design_info.column_names, 'coef': model.coef_[0,:]})
df.sort_values('coef', ascending=False, inplace=True)
df

# %% [markdown]
# #### Optional: Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients. Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary. Which entries have the highest predicted salaries?

# %% [markdown]
# # Bonus Section: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are most valuable?

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform()

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(model, X_scaled, y, cv=3, scoring=metric)
    print(metric, scores.mean(), scores.std())

# %%
model.fit(X_scaled, y)

df = pd.DataFrame({'features' : vectorizer.get_feature_names(), 'coef': model.coef_[0,:]})
df.sort_values('coef', ascending=False, inplace=True)

# %%
df.head()

# %%
df.tail()

# %%
# retest L1 and L2 regularization
from sklearn.linear_model import LogisticRegressionCV

model = LogisticRegressionCV()

# %% [markdown]
# Score: | /24
# ------|-------
# Identify: Problem Statement and Hypothesis |
# Acquire: Import Data using BeautifulSoup|
# Parse: Clean and Organize Data|
# Model: Perform Logistic Regression|
# Evaluate: Logistic Regression Results	|
# Present: Blog Report with Findings and Recommendations		|
# Interactive Tableau visualizations |
# Regularization |
# Bonus: Countvectorizer  |
